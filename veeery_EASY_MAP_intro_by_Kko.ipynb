# %% [markdown]
# # Very easy intro for data scientists with no clue of geodata but wish for a map.
#
# **About geodata**
#
# there's a lot of theory behind geodata (whole university programms like geodesy etc) because basically
# - some bright spot found out, that the earth is round    =======> (3D-) globe with a geogr. coordinate system   (issue #1: latitude and longitude)
# - some seafearing brothers wanted to use that knowledge  ====> flat (2D-) map with coordinate grid           (issue #2: projection)
# - some researchers obsessed over accuracy   ==============> not a globe but an ellipsoid                  (issue #3: epsg and transformations)
# - now satellites are of the opinion, that the earth is a potato ====> or a geoide ... well, anyway..           (i hesitate to even - hm ...
#
# ... we'll talk about that along the way in easily digestible portions.
#
# **And how to deal with this mess?**
#
# - geometry dtype, shapes (points, lines, polygones), shp-files.
# - maybe we talk a bit about discrete data: vector, raster, (lidar, point cloud).
# - and of course: handling the '#issues'.
#
# **On the bright side:**
#
# geodata is the _MOTHER OF MERGABILITY!_ As soon as you know where something is, you can merge everything with everything ON 'location'. That's called the _'SPATIAL JOIN'_.
#
# Imagine you have the 'height above sea level' and rainfall data. You then can calculate drain rates, flooding hazards and ... a lot of things. Or you get a 'layer' with all roads along with your flooding data. Then you can tell, which roads are passable, which will be passable when water level drops by 20 cm ... and so on. (Let's mention here the strange custom to handle data as 'layers'. You can add to e.g. a topographic 'basemap' additional (data-)layers with infrastructure (roads, cities), with socio-economic data (population, employment) or a layer 'orthophoto' etc.)
#
# And of course, there is the advantage of visualisation by _MAPs_.
#
# **So now,**
#
# let's start with a first map!

# %% [markdown]
# # Make a map with folium library
# documentation: https://python-visualization.github.io/folium/latest/

# %% [markdown]
# **ingredient list**
# - folium.Map()
# - data with latitude and longitude as float
#
# **output**
# - map based on open street map (OSM) = 'basemap'
# - with markers for the data = 'layer'
# - and heatmap for population layer

# %% [markdown]
# ## Import library and data

# %%
# pip install folium
import pandas as pd
import folium

# %%
# load cities data 
# with latitude and longitude as float

data = pd.read_csv("data/some_de_cities.csv", index_col=None)
data.head(2)
# Out:
#         city  latitude  longitude  country iso2         Bundesland  population
# 0     Berlin   52.5200     13.405  Germany   DE             Berlin   4473101.0
# 1  Stuttgart   48.7775      9.180  Germany   DE  Baden-Württemberg   2787724.0

# %% [markdown]
# This data gives us Cities with location data and other data values for populations.
#
# From that we will first
# - create a topographic basemap using open street map (OSM)
# - then add a data layer with markers for cities
# - and then add a data layer with heatmap for population.
#
# !Vamos!
#
# .

# %% [markdown]
# ## Create Basemap (OSM)

# %%
# create basemap = openstreetmap (OSM)
# with center='middle of Germany' (latitude=51.57, longitude=14.37)

map = folium.Map([51.57, 14.37], zoom_start=6)
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_d3b8cb573cd48ed9a87e23ad1ddbfdea {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_d3b8cb573cd48ed9a87e23ad1ddbfdea&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_d3b8cb573cd48ed9a87e23ad1ddbfdea = L.map(
#                 &quot;map_d3b8cb573cd48ed9a87e23ad1ddbfdea&quot;,
#                 {
#                     center: [51.57, 14.37],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 6,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_9ddd88a718c1366c649fec1ba33b43cd = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_9ddd88a718c1366c649fec1ba33b43cd.addTo(map_d3b8cb573cd48ed9a87e23ad1ddbfdea);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# much too easy, isn't it?
#
#
# .

# %% [markdown]
# ## Add data layer: cities

# %%
# add data layer to basemap
# with markers for cities

for i, row in data.iterrows():
    folium.Marker([row['latitude'], row['longitude']], popup=row['city']
    ).add_to(map)

# %%
map.save('results/cities_de.html')

# %%
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_d3b8cb573cd48ed9a87e23ad1ddbfdea {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_d3b8cb573cd48ed9a87e23ad1ddbfdea&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_d3b8cb573cd48ed9a87e23ad1ddbfdea = L.map(
#                 &quot;map_d3b8cb573cd48ed9a87e23ad1ddbfdea&quot;,
#                 {
#                     center: [51.57, 14.37],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 6,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_9ddd88a718c1366c649fec1ba33b43cd = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_9ddd88a718c1366c649fec1ba33b43cd.addTo(map_d3b8cb573cd48ed9a87e23ad1ddbfdea);
#
#
#             tile_layer_9ddd88a718c1366c649fec1ba33b43cd.addTo(map_d3b8cb573cd48ed9a87e23ad1ddbfdea);
#
#
#             var marker_5a413edc55c868af3e7c6cd7124cf9ff = L.marker(
#                 [52.52, 13.405],
#                 {}
#             ).addTo(map_d3b8cb573cd48ed9a87e23ad1ddbfdea);
#
#
#         var popup_9bdea985669c991b4422dbbef19dbbf8 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_39ff53a6fc06ed31764bb4ef852099a9 = $(`&lt;div id=&quot;html_39ff53a6fc06ed31764bb4ef852099a9&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Berlin&lt;/div&gt;`)[0];
#                 popup_9bdea985669c991b4422dbbef19dbbf8.setContent(html_39ff53a6fc06ed31764bb4ef852099a9);
#
#
#
#         marker_5a413edc55c868af3e7c6cd7124cf9ff.bindPopup(popup_9bdea985669c991b4422dbbef19dbbf8)
#         ;
#
#
#
#
#             var marker_900e8da6012e28024af738551a7aa9c4 = L.marker(
#                 [48.7775, 9.18],
#                 {}
#             ).addTo(map_d3b8cb573cd48ed9a87e23ad1ddbfdea);
#
#
#         var popup_a58f3cfcc21e7671cd538d019a9f6b90 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_1439cb2868c5f16735c2e143e30177d9 = $(`&lt;div id=&quot;html_1439cb2868c5f16735c2e143e30177d9&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Stuttgart&lt;/div&gt;`)[0];
#                 popup_a58f3cfcc21e7671cd538d019a9f6b90.setContent(html_1439cb2868c5f16735c2e143e30177d9);
#
#
#
#         marker_900e8da6012e28024af738551a7aa9c4.bindPopup(popup_a58f3cfcc21e7671cd538d019a9f6b90)
#         ;
#
#
#
#
#             var marker_ccad037559229c854888a97ba84d1ac3 = L.marker(
#                 [48.1375, 11.575],
#                 {}
#             ).addTo(map_d3b8cb573cd48ed9a87e23ad1ddbfdea);
#
#
#         var popup_7b8f8b42a7037f7af59ec6eed3b7f4ca = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_a67dc923f2e7053289f646c892f07492 = $(`&lt;div id=&quot;html_a67dc923f2e7053289f646c892f07492&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Munich&lt;/div&gt;`)[0];
#                 popup_7b8f8b42a7037f7af59ec6eed3b7f4ca.setContent(html_a67dc923f2e7053289f646c892f07492);
#
#
#
#         marker_ccad037559229c854888a97ba84d1ac3.bindPopup(popup_7b8f8b42a7037f7af59ec6eed3b7f4ca)
#         ;
#
#
#
#
#             var marker_a1ed6922d1bc5a035c8f22e797b79c43 = L.marker(
#                 [53.55, 10.0],
#                 {}
#             ).addTo(map_d3b8cb573cd48ed9a87e23ad1ddbfdea);
#
#
#         var popup_dcebe0fa017b56f87f8f6118bb4da4ef = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_9efbf26aef87cfc85aa5ecb528079b54 = $(`&lt;div id=&quot;html_9efbf26aef87cfc85aa5ecb528079b54&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Hamburg&lt;/div&gt;`)[0];
#                 popup_dcebe0fa017b56f87f8f6118bb4da4ef.setContent(html_9efbf26aef87cfc85aa5ecb528079b54);
#
#
#
#         marker_a1ed6922d1bc5a035c8f22e797b79c43.bindPopup(popup_dcebe0fa017b56f87f8f6118bb4da4ef)
#         ;
#
#
#
#
#             var marker_37f0eb0b72060f127cc36515bf82efe9 = L.marker(
#                 [50.9364, 6.9528],
#                 {}
#             ).addTo(map_d3b8cb573cd48ed9a87e23ad1ddbfdea);
#
#
#         var popup_ae9e5330e0962900c82b3ebe69322ff1 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_5d260ab42d5c3674cec2b428d255938c = $(`&lt;div id=&quot;html_5d260ab42d5c3674cec2b428d255938c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Cologne&lt;/div&gt;`)[0];
#                 popup_ae9e5330e0962900c82b3ebe69322ff1.setContent(html_5d260ab42d5c3674cec2b428d255938c);
#
#
#
#         marker_37f0eb0b72060f127cc36515bf82efe9.bindPopup(popup_ae9e5330e0962900c82b3ebe69322ff1)
#         ;
#
#
#
#
#             var marker_90a361fcec0a9e71b60a93ca226e6854 = L.marker(
#                 [50.1106, 8.6822],
#                 {}
#             ).addTo(map_d3b

# %% [markdown]
# You just made your first map, congratulations!
#
#
#
#
# .

# %% [markdown]
# **Change marker symbols to 'CircleMarkers'**

# %%
# create basemap OSM
map = folium.Map([51.57, 14.37], zoom_start=6)

# add data layer cities
for i, row in data.iterrows():
    folium.CircleMarker([row['latitude'], row['longitude']], popup=row['city'], radius=5, color='green', fill=True, fill_color='black'
    ).add_to(map)
    
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_0e97966ac7d63c05bb01bec16429eaee {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_0e97966ac7d63c05bb01bec16429eaee&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_0e97966ac7d63c05bb01bec16429eaee = L.map(
#                 &quot;map_0e97966ac7d63c05bb01bec16429eaee&quot;,
#                 {
#                     center: [51.57, 14.37],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 6,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_bd97ec30538141cb6f495714fc92f3a2 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_bd97ec30538141cb6f495714fc92f3a2.addTo(map_0e97966ac7d63c05bb01bec16429eaee);
#
#
#             var circle_marker_4bce8d210f118b93a8a4531de8d0c82b = L.circleMarker(
#                 [52.52, 13.405],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;green&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;black&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 5, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_0e97966ac7d63c05bb01bec16429eaee);
#
#
#         var popup_8e6a6b27a136a21a931b41958068baed = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_702e6ba2ce00dc0af9e129595a1e8f84 = $(`&lt;div id=&quot;html_702e6ba2ce00dc0af9e129595a1e8f84&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Berlin&lt;/div&gt;`)[0];
#                 popup_8e6a6b27a136a21a931b41958068baed.setContent(html_702e6ba2ce00dc0af9e129595a1e8f84);
#
#
#
#         circle_marker_4bce8d210f118b93a8a4531de8d0c82b.bindPopup(popup_8e6a6b27a136a21a931b41958068baed)
#         ;
#
#
#
#
#             var circle_marker_91889eb1eb67fb4ab7b18937b42a4e85 = L.circleMarker(
#                 [48.7775, 9.18],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;green&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;black&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 5, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_0e97966ac7d63c05bb01bec16429eaee);
#
#
#         var popup_90f86ffad02b8caa23743aaca74af0cb = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_d5e37476968f4818a9ff905ea90b993b = $(`&lt;div id=&quot;html_d5e37476968f4818a9ff905ea90b993b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Stuttgart&lt;/div&gt;`)[0];
#                 popup_90f86ffad02b8caa23743aaca74af0cb.setContent(html_d5e37476968f4818a9ff905ea90b993b);
#
#
#
#         circle_marker_91889eb1eb67fb4ab7b18937b42a4e85.bindPopup(popup_90f86ffad02b8caa23743aaca74af0cb)
#         ;
#
#
#
#
#             var circle_marker_ea297574c2c76e584ec6097440ca90a4 = L.circleMarker(
#                 [48.1375, 11.575],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;green&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;black&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 5, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_0e97966ac7d63c05bb01bec16429eaee);
#
#
#         var popup_d9b1b3ca263d05160c0743a5b0339de7 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_9c9bc35cc4e5ca965651b7fa893a52e1 = $(`&lt;div id=&quot;html_9c9bc35cc4e5ca965651b7fa893a52e1&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Munich&lt;/div&gt;`)[0];
#                 popup_d9b1b3ca263d05160c0743a5b0339de7.setContent(html_9c9bc35cc4e5ca965651b7fa893a52e1);
#
#
#
#         circle_marker_ea297574c2c76e584ec6097440ca90a4.bindPopup(popup_d9b1b3ca263d05160c0743a5b0339de7)
#         ;
#
#
#
#
#             var circle_marker_f95195a98d768f5959ab4b3a2de4d47f = L.circleMarker(
#                 [53.55, 10.0],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;green&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;black&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &q

# %% [markdown]
# ## Add heatmap layer: population

# %%
from folium.plugins import HeatMap

# prepate heatmap_data
hm_data = []
for i, row in data.iterrows():
    hm_data.append([row['latitude'], row['longitude'], row['population']])

# add heatmap layer to map
HeatMap(hm_data
    ).add_to(map)
    
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_0e97966ac7d63c05bb01bec16429eaee {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium@main/folium/templates/leaflet_heat.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_0e97966ac7d63c05bb01bec16429eaee&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_0e97966ac7d63c05bb01bec16429eaee = L.map(
#                 &quot;map_0e97966ac7d63c05bb01bec16429eaee&quot;,
#                 {
#                     center: [51.57, 14.37],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 6,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_bd97ec30538141cb6f495714fc92f3a2 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_bd97ec30538141cb6f495714fc92f3a2.addTo(map_0e97966ac7d63c05bb01bec16429eaee);
#
#
#             var circle_marker_4bce8d210f118b93a8a4531de8d0c82b = L.circleMarker(
#                 [52.52, 13.405],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;green&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;black&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 5, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_0e97966ac7d63c05bb01bec16429eaee);
#
#
#         var popup_8e6a6b27a136a21a931b41958068baed = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_702e6ba2ce00dc0af9e129595a1e8f84 = $(`&lt;div id=&quot;html_702e6ba2ce00dc0af9e129595a1e8f84&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Berlin&lt;/div&gt;`)[0];
#                 popup_8e6a6b27a136a21a931b41958068baed.setContent(html_702e6ba2ce00dc0af9e129595a1e8f84);
#
#
#
#         circle_marker_4bce8d210f118b93a8a4531de8d0c82b.bindPopup(popup_8e6a6b27a136a21a931b41958068baed)
#         ;
#
#
#
#
#             var circle_marker_91889eb1eb67fb4ab7b18937b42a4e85 = L.circleMarker(
#                 [48.7775, 9.18],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;green&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;black&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 5, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_0e97966ac7d63c05bb01bec16429eaee);
#
#
#         var popup_90f86ffad02b8caa23743aaca74af0cb = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_d5e37476968f4818a9ff905ea90b993b = $(`&lt;div id=&quot;html_d5e37476968f4818a9ff905ea90b993b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Stuttgart&lt;/div&gt;`)[0];
#                 popup_90f86ffad02b8caa23743aaca74af0cb.setContent(html_d5e37476968f4818a9ff905ea90b993b);
#
#
#
#         circle_marker_91889eb1eb67fb4ab7b18937b42a4e85.bindPopup(popup_90f86ffad02b8caa23743aaca74af0cb)
#         ;
#
#
#
#
#             var circle_marker_ea297574c2c76e584ec6097440ca90a4 = L.circleMarker(
#                 [48.1375, 11.575],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;green&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;black&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 5, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_0e97966ac7d63c05bb01bec16429eaee);
#
#
#         var popup_d9b1b3ca263d05160c0743a5b0339de7 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_9c9bc35cc4e5ca965651b7fa893a52e1 = $(`&lt;div id=&quot;html_9c9bc35cc4e5ca965651b7fa893a52e1&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Munich&lt;/div&gt;`)[0];
#                 popup_d9b1b3ca263d05160c0743a5b0339de7.setContent(html_9c9bc35cc4e5ca965651b7fa893a52e1);
#
#
#
#         circle_marker_ea297574c2c76e584ec6097440ca90a4.bindPopup(popup_d9b1b3ca263d05160c0743a5b0339de7)
#         ;
#
#
#
#
#             var circle_marker_f95195a98d768f5959ab4b3a2de4d47f = L.circleMarker(
#                 [53.55, 10.0],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;green&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;:

# %% [markdown]
# Well done! You've already created a basemap with two layers :)
#
#
#
# .

# %% [markdown]
# # _Concessions_
#
# _I know i promised more in the introduction, and i intend to continue here with geopandas and geometry format._
#
# _But -sadly- it's time for bed now._
#
# _You've made your first map! So stopp nagging :)_
#
# _Good n8 and CU soon!_

# %% [markdown]
# # Conclusion as send off for the night -haha-

# %%
def folium_map():
    import pandas as pd
    import folium
    from folium.plugins import HeatMap

    # load data with latitude and lognitude as float
    data = pd.read_csv("data/some_de_cities.csv", index_col=None)

    # create basemap OSM
    map = folium.Map([51.57, 14.37], zoom_start=6)

    # add data layer cities
    for i, row in data.iterrows():
        folium.CircleMarker([row['latitude'], row['longitude']], popup=row['city'], radius=1.2, color='darkblue'
        ).add_to(map)

    # prepate heatmap_data
    hm_data = []
    for i, row in data.iterrows():
        hm_data.append([row['latitude'], row['longitude'], row['population']])

    # add heatmap layer population
    HeatMap(hm_data
        ).add_to(map)
    return map

# %%
folium_map()
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_d13a1f6f9a956836010504565b301627 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium@main/folium/templates/leaflet_heat.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_d13a1f6f9a956836010504565b301627&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_d13a1f6f9a956836010504565b301627 = L.map(
#                 &quot;map_d13a1f6f9a956836010504565b301627&quot;,
#                 {
#                     center: [51.57, 14.37],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 6,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_a2229ee3a25ad5832e4bd0c36a9278cb = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_a2229ee3a25ad5832e4bd0c36a9278cb.addTo(map_d13a1f6f9a956836010504565b301627);
#
#
#             var circle_marker_258c072ec9fbbe12df7fa292e7984729 = L.circleMarker(
#                 [52.52, 13.405],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;darkblue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;darkblue&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 1.2, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_d13a1f6f9a956836010504565b301627);
#
#
#         var popup_9eb12913478549a278ca876c429b5092 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_31b282663c507fceb09b507af1a75424 = $(`&lt;div id=&quot;html_31b282663c507fceb09b507af1a75424&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Berlin&lt;/div&gt;`)[0];
#                 popup_9eb12913478549a278ca876c429b5092.setContent(html_31b282663c507fceb09b507af1a75424);
#
#
#
#         circle_marker_258c072ec9fbbe12df7fa292e7984729.bindPopup(popup_9eb12913478549a278ca876c429b5092)
#         ;
#
#
#
#
#             var circle_marker_80604ffe178f96cc662064ab17dd8d73 = L.circleMarker(
#                 [48.7775, 9.18],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;darkblue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;darkblue&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 1.2, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_d13a1f6f9a956836010504565b301627);
#
#
#         var popup_485c2422287fc888e3b89116377c6215 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_e85fdb1438561f66b37375708e96bf4b = $(`&lt;div id=&quot;html_e85fdb1438561f66b37375708e96bf4b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Stuttgart&lt;/div&gt;`)[0];
#                 popup_485c2422287fc888e3b89116377c6215.setContent(html_e85fdb1438561f66b37375708e96bf4b);
#
#
#
#         circle_marker_80604ffe178f96cc662064ab17dd8d73.bindPopup(popup_485c2422287fc888e3b89116377c6215)
#         ;
#
#
#
#
#             var circle_marker_5c0e99de29cf22122b20cc0402193de8 = L.circleMarker(
#                 [48.1375, 11.575],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;darkblue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;darkblue&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 1.2, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_d13a1f6f9a956836010504565b301627);
#
#
#         var popup_4090a01860c9e630425e262eb77e755d = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_1f3eaccc3ed86dddda8f5ae8be57dc4a = $(`&lt;div id=&quot;html_1f3eaccc3ed86dddda8f5ae8be57dc4a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Munich&lt;/div&gt;`)[0];
#                 popup_4090a01860c9e630425e262eb77e755d.setContent(html_1f3eaccc3ed86dddda8f5ae8be57dc4a);
#
#
#
#         circle_marker_5c0e99de29cf22122b20cc0402193de8.bindPopup(popup_4090a01860c9e630425e262eb77e755d)
#         ;
#
#
#
#
#             var circle_marker_1f5ceafbbd1bbfc26a68823ddc23f162 = L.circleMarker(
#                 [53.55, 10.0],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;darkblue&quot;, &quot;dashArray&quot;:
