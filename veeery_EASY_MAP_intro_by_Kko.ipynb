# %% [markdown]
# # Very easy intro for data scientists with no clue of geodata but wish for a map.
#
# **About geodata**
#
# there's a lot of theory behind geodata (whole university programms like geodesy etc) because basically
# - some bright spot found out, that the earth is round    =======> (3D-) globe with a geogr. coordinate system   (issue #1: latitude and longitude)
# - some seafearing brothers wanted to use that knowledge  ====> flat (2D-) map with coordinate grid           (issue #2: projection)
# - some researchers obsessed over accuracy   ==============> not a globe but an ellipsoid                  (issue #3: epsg and transformations)
# - now satellites are of the opinion, that the earth is a potato ====> or a geoide ... well, anyway..           (i hesitate to even - hm ...
#
# ... we'll talk about that along the way in easily digestible portions.
#
# **And how to deal with this mess?**
#
# - geometry dtype, shapes (points, lines, polygones), shp-files.
# - maybe we talk a bit about discrete data: vector, raster, (lidar, point cloud).
# - and of course: handling the '#issues'.
#
# **On the bright side:**
#
# geodata is the _MOTHER OF MERGABILITY!_ As soon as you know where something is, you can merge everything with everything ON 'location'. That's called the _'SPATIAL JOIN'_.
#
# Imagine you have the 'height above sea level' and rainfall data. You then can calculate drain rates, flooding hazards and ... a lot of things. Or you get a 'layer' with all roads along with your flooding data. Then you can tell, which roads are passable, which will be passable when water level drops by 20 cm ... and so on. (Let's mention here the strange custom to handle data as 'layers'. You can add to e.g. a topographic 'basemap' additional (data-)layers with infrastructure (roads, cities), with socio-economic data (population, employment) or a layer 'orthophoto' etc.)
#
# And of course, there is the advantage of visualisation by _MAPs_.
#
# **So now,**
#
# let's start with a first map!

# %% [markdown]
# # Make a map with folium library
# documentation: https://python-visualization.github.io/folium/latest/

# %% [markdown]
# **ingredient list**
# - folium.Map()
# - data with latitude and longitude as float
#
# **output**
# - map based on open street map (OSM) = 'basemap'
# - with markers for the data = 'layer'
# - and heatmap for population layer

# %% [markdown]
# ## Import library and data

# %%
# pip install folium
import pandas as pd
import folium

# %%
# load cities data 
# with latitude and longitude as float

data = pd.read_csv("some_de_cities.csv", index_col=None)
data.head(2)
# Out:
#         city  latitude  longitude  country iso2         Bundesland  population
# 0     Berlin   52.5200     13.405  Germany   DE             Berlin   4473101.0
# 1  Stuttgart   48.7775      9.180  Germany   DE  Baden-Württemberg   2787724.0

# %% [markdown]
# This data gives us Cities with location data and other data values for populations.
#
# From that we will first
# - create a topographic basemap using open street map (OSM)
# - then add a data layer with markers for cities
# - and then add a data layer with heatmap for population.
#
# !Vamos!
#
# .

# %% [markdown]
# ## Create Basemap (OSM)

# %%
# create basemap = openstreetmap (OSM)
# with center='middle of Germany' (latitude=51.57, longitude=14.37)

map = folium.Map([51.57, 14.37], zoom_start=6)
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_0a6569fc13ffe0b053046d285965346f {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_0a6569fc13ffe0b053046d285965346f&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_0a6569fc13ffe0b053046d285965346f = L.map(
#                 &quot;map_0a6569fc13ffe0b053046d285965346f&quot;,
#                 {
#                     center: [51.57, 14.37],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 6,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_3200d7bfeb19f7b0893e6f7f15602b74 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_3200d7bfeb19f7b0893e6f7f15602b74.addTo(map_0a6569fc13ffe0b053046d285965346f);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# much too easy, isn't it?
#
#
# .

# %% [markdown]
# ## Add data layer: cities

# %%
# add data layer to basemap
# with markers for cities

for i, row in data.iterrows():
    folium.Marker([row['latitude'], row['longitude']], popup=row['city']
    ).add_to(map)

# %%
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_0a6569fc13ffe0b053046d285965346f {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_0a6569fc13ffe0b053046d285965346f&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_0a6569fc13ffe0b053046d285965346f = L.map(
#                 &quot;map_0a6569fc13ffe0b053046d285965346f&quot;,
#                 {
#                     center: [51.57, 14.37],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 6,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_3200d7bfeb19f7b0893e6f7f15602b74 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_3200d7bfeb19f7b0893e6f7f15602b74.addTo(map_0a6569fc13ffe0b053046d285965346f);
#
#
#             tile_layer_3200d7bfeb19f7b0893e6f7f15602b74.addTo(map_0a6569fc13ffe0b053046d285965346f);
#
#
#             var marker_ec81d8290135cce5c9b7b91895d8420a = L.marker(
#                 [52.52, 13.405],
#                 {}
#             ).addTo(map_0a6569fc13ffe0b053046d285965346f);
#
#
#         var popup_6128bab418cdc83a808f3e59a0a9ddf3 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_1b136c5e554c67430209f7fdf34ef16d = $(`&lt;div id=&quot;html_1b136c5e554c67430209f7fdf34ef16d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Berlin&lt;/div&gt;`)[0];
#                 popup_6128bab418cdc83a808f3e59a0a9ddf3.setContent(html_1b136c5e554c67430209f7fdf34ef16d);
#
#
#
#         marker_ec81d8290135cce5c9b7b91895d8420a.bindPopup(popup_6128bab418cdc83a808f3e59a0a9ddf3)
#         ;
#
#
#
#
#             var marker_a351f28e82fa6214ba83169b65a4f129 = L.marker(
#                 [48.7775, 9.18],
#                 {}
#             ).addTo(map_0a6569fc13ffe0b053046d285965346f);
#
#
#         var popup_39e74f3ba89278d6eb3843fe6ba7a69b = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_4f141dff8dde8e821aa4836e34c2519d = $(`&lt;div id=&quot;html_4f141dff8dde8e821aa4836e34c2519d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Stuttgart&lt;/div&gt;`)[0];
#                 popup_39e74f3ba89278d6eb3843fe6ba7a69b.setContent(html_4f141dff8dde8e821aa4836e34c2519d);
#
#
#
#         marker_a351f28e82fa6214ba83169b65a4f129.bindPopup(popup_39e74f3ba89278d6eb3843fe6ba7a69b)
#         ;
#
#
#
#
#             var marker_8d925f3de463363f5f079cc9885b32ca = L.marker(
#                 [48.1375, 11.575],
#                 {}
#             ).addTo(map_0a6569fc13ffe0b053046d285965346f);
#
#
#         var popup_1decf9761ad5001942cde4f93de99047 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_7e97f38229b7b24c2d6b59609b5c9688 = $(`&lt;div id=&quot;html_7e97f38229b7b24c2d6b59609b5c9688&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Munich&lt;/div&gt;`)[0];
#                 popup_1decf9761ad5001942cde4f93de99047.setContent(html_7e97f38229b7b24c2d6b59609b5c9688);
#
#
#
#         marker_8d925f3de463363f5f079cc9885b32ca.bindPopup(popup_1decf9761ad5001942cde4f93de99047)
#         ;
#
#
#
#
#             var marker_29f835037e2ac0bf3397ceca412aab0a = L.marker(
#                 [53.55, 10.0],
#                 {}
#             ).addTo(map_0a6569fc13ffe0b053046d285965346f);
#
#
#         var popup_ccb71098e5b7b992a2795ab3ba34798e = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_bdeaff14975c1c060a4cb3d5a6d35d2a = $(`&lt;div id=&quot;html_bdeaff14975c1c060a4cb3d5a6d35d2a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Hamburg&lt;/div&gt;`)[0];
#                 popup_ccb71098e5b7b992a2795ab3ba34798e.setContent(html_bdeaff14975c1c060a4cb3d5a6d35d2a);
#
#
#
#         marker_29f835037e2ac0bf3397ceca412aab0a.bindPopup(popup_ccb71098e5b7b992a2795ab3ba34798e)
#         ;
#
#
#
#
#             var marker_5b3e54d507d56eaded71ee3399744427 = L.marker(
#                 [50.9364, 6.9528],
#                 {}
#             ).addTo(map_0a6569fc13ffe0b053046d285965346f);
#
#
#         var popup_64d6fdd7782f1c31ee1a6bf791f4e059 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_e164ad58d296371d7441e6dfaed4e5a9 = $(`&lt;div id=&quot;html_e164ad58d296371d7441e6dfaed4e5a9&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Cologne&lt;/div&gt;`)[0];
#                 popup_64d6fdd7782f1c31ee1a6bf791f4e059.setContent(html_e164ad58d296371d7441e6dfaed4e5a9);
#
#
#
#         marker_5b3e54d507d56eaded71ee3399744427.bindPopup(popup_64d6fdd7782f1c31ee1a6bf791f4e059)
#         ;
#
#
#
#
#             var marker_af62c40aea420f9645f3f287ed36a447 = L.marker(
#                 [50.1106, 8.6822],
#                 {}
#             ).addTo(map_0a6

# %% [markdown]
# You just made your first map, congratulations!
#
#
#
#
# .

# %% [markdown]
# **Change marker symbols to 'CircleMarkers'**

# %%
# create basemap OSM
map = folium.Map([51.57, 14.37], zoom_start=6)

# add data layer cities
for i, row in data.iterrows():
    folium.CircleMarker([row['latitude'], row['longitude']], popup=row['city'], radius=5, color='green', fill=True, fill_color='black'
    ).add_to(map)
    
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_9e24854e510b0fd4f2360dd5c79fc963 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_9e24854e510b0fd4f2360dd5c79fc963&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_9e24854e510b0fd4f2360dd5c79fc963 = L.map(
#                 &quot;map_9e24854e510b0fd4f2360dd5c79fc963&quot;,
#                 {
#                     center: [51.57, 14.37],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 6,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_2ea9ebb49f16d409f503ee3cf992c325 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_2ea9ebb49f16d409f503ee3cf992c325.addTo(map_9e24854e510b0fd4f2360dd5c79fc963);
#
#
#             var circle_marker_c6858070f96e344b204d4c8c52a85b5d = L.circleMarker(
#                 [52.52, 13.405],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;green&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;black&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 5, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_9e24854e510b0fd4f2360dd5c79fc963);
#
#
#         var popup_647fb1a34ab881168af4c135ecf14d12 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_0164020bf328481a094fd6e2571aa73e = $(`&lt;div id=&quot;html_0164020bf328481a094fd6e2571aa73e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Berlin&lt;/div&gt;`)[0];
#                 popup_647fb1a34ab881168af4c135ecf14d12.setContent(html_0164020bf328481a094fd6e2571aa73e);
#
#
#
#         circle_marker_c6858070f96e344b204d4c8c52a85b5d.bindPopup(popup_647fb1a34ab881168af4c135ecf14d12)
#         ;
#
#
#
#
#             var circle_marker_c1d31837d772b9c9df0d73571ab9f9e3 = L.circleMarker(
#                 [48.7775, 9.18],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;green&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;black&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 5, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_9e24854e510b0fd4f2360dd5c79fc963);
#
#
#         var popup_0eb0264492f529b53c175e749cfa2fcc = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_68208ae022eca2c937d54aed0d9fb60f = $(`&lt;div id=&quot;html_68208ae022eca2c937d54aed0d9fb60f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Stuttgart&lt;/div&gt;`)[0];
#                 popup_0eb0264492f529b53c175e749cfa2fcc.setContent(html_68208ae022eca2c937d54aed0d9fb60f);
#
#
#
#         circle_marker_c1d31837d772b9c9df0d73571ab9f9e3.bindPopup(popup_0eb0264492f529b53c175e749cfa2fcc)
#         ;
#
#
#
#
#             var circle_marker_7ebee3751a6b8172b662d4cc1b82d5ae = L.circleMarker(
#                 [48.1375, 11.575],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;green&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;black&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 5, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_9e24854e510b0fd4f2360dd5c79fc963);
#
#
#         var popup_dc4af36c971258870f38c67beff5a148 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_f1016d7e0294ed79154eefb26403cc5e = $(`&lt;div id=&quot;html_f1016d7e0294ed79154eefb26403cc5e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Munich&lt;/div&gt;`)[0];
#                 popup_dc4af36c971258870f38c67beff5a148.setContent(html_f1016d7e0294ed79154eefb26403cc5e);
#
#
#
#         circle_marker_7ebee3751a6b8172b662d4cc1b82d5ae.bindPopup(popup_dc4af36c971258870f38c67beff5a148)
#         ;
#
#
#
#
#             var circle_marker_e205ca644d4f7deb2932ebc5c05dfd2a = L.circleMarker(
#                 [53.55, 10.0],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;green&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;black&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &q

# %% [markdown]
# ## Add heatmap layer: population

# %%
from folium.plugins import HeatMap

# prepate heatmap_data
hm_data = []
for i, row in data.iterrows():
    hm_data.append([row['latitude'], row['longitude'], row['population']])

# add heatmap layer to map
HeatMap(hm_data
    ).add_to(map)
    
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_9e24854e510b0fd4f2360dd5c79fc963 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium@main/folium/templates/leaflet_heat.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_9e24854e510b0fd4f2360dd5c79fc963&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_9e24854e510b0fd4f2360dd5c79fc963 = L.map(
#                 &quot;map_9e24854e510b0fd4f2360dd5c79fc963&quot;,
#                 {
#                     center: [51.57, 14.37],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 6,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_2ea9ebb49f16d409f503ee3cf992c325 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_2ea9ebb49f16d409f503ee3cf992c325.addTo(map_9e24854e510b0fd4f2360dd5c79fc963);
#
#
#             var circle_marker_c6858070f96e344b204d4c8c52a85b5d = L.circleMarker(
#                 [52.52, 13.405],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;green&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;black&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 5, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_9e24854e510b0fd4f2360dd5c79fc963);
#
#
#         var popup_647fb1a34ab881168af4c135ecf14d12 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_0164020bf328481a094fd6e2571aa73e = $(`&lt;div id=&quot;html_0164020bf328481a094fd6e2571aa73e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Berlin&lt;/div&gt;`)[0];
#                 popup_647fb1a34ab881168af4c135ecf14d12.setContent(html_0164020bf328481a094fd6e2571aa73e);
#
#
#
#         circle_marker_c6858070f96e344b204d4c8c52a85b5d.bindPopup(popup_647fb1a34ab881168af4c135ecf14d12)
#         ;
#
#
#
#
#             var circle_marker_c1d31837d772b9c9df0d73571ab9f9e3 = L.circleMarker(
#                 [48.7775, 9.18],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;green&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;black&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 5, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_9e24854e510b0fd4f2360dd5c79fc963);
#
#
#         var popup_0eb0264492f529b53c175e749cfa2fcc = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_68208ae022eca2c937d54aed0d9fb60f = $(`&lt;div id=&quot;html_68208ae022eca2c937d54aed0d9fb60f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Stuttgart&lt;/div&gt;`)[0];
#                 popup_0eb0264492f529b53c175e749cfa2fcc.setContent(html_68208ae022eca2c937d54aed0d9fb60f);
#
#
#
#         circle_marker_c1d31837d772b9c9df0d73571ab9f9e3.bindPopup(popup_0eb0264492f529b53c175e749cfa2fcc)
#         ;
#
#
#
#
#             var circle_marker_7ebee3751a6b8172b662d4cc1b82d5ae = L.circleMarker(
#                 [48.1375, 11.575],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;green&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;black&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 5, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_9e24854e510b0fd4f2360dd5c79fc963);
#
#
#         var popup_dc4af36c971258870f38c67beff5a148 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_f1016d7e0294ed79154eefb26403cc5e = $(`&lt;div id=&quot;html_f1016d7e0294ed79154eefb26403cc5e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Munich&lt;/div&gt;`)[0];
#                 popup_dc4af36c971258870f38c67beff5a148.setContent(html_f1016d7e0294ed79154eefb26403cc5e);
#
#
#
#         circle_marker_7ebee3751a6b8172b662d4cc1b82d5ae.bindPopup(popup_dc4af36c971258870f38c67beff5a148)
#         ;
#
#
#
#
#             var circle_marker_e205ca644d4f7deb2932ebc5c05dfd2a = L.circleMarker(
#                 [53.55, 10.0],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;green&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;:

# %% [markdown]
# Well done! You've already created a basemap with two layers :)
#
#
#
# .

# %% [markdown]
# # _Concessions_
#
# _I know i promised more in the introduction, and i intend to continue here with geopandas and geometry format._
#
# _But -sadly- it's time for bed now._
#
# _You've made your first map! So stopp nagging :)_
#
# _Good n8 and CU soon!_

# %% [markdown]
# # Conclusion as send off for the night -haha-

# %%
def folium_map():
    import pandas as pd
    import folium
    from folium.plugins import HeatMap

    # load data with latitude and lognitude as float
    data = pd.read_csv("some_de_cities.csv", index_col=None)

    # create basemap OSM
    map = folium.Map([51.57, 14.37], zoom_start=6)

    # add data layer cities
    for i, row in data.iterrows():
        folium.CircleMarker([row['latitude'], row['longitude']], popup=row['city'], radius=1.2, color='darkblue'
        ).add_to(map)

    # prepate heatmap_data
    hm_data = []
    for i, row in data.iterrows():
        hm_data.append([row['latitude'], row['longitude'], row['population']])

    # add heatmap layer population
    HeatMap(hm_data
        ).add_to(map)
    return map

# %%
map.save('map_cities_population.html')

# %%
folium_map()
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_c552b838e939d52b6b1d0e0d602d48a5 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium@main/folium/templates/leaflet_heat.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_c552b838e939d52b6b1d0e0d602d48a5&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_c552b838e939d52b6b1d0e0d602d48a5 = L.map(
#                 &quot;map_c552b838e939d52b6b1d0e0d602d48a5&quot;,
#                 {
#                     center: [51.57, 14.37],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 6,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_51ba61a82d941ab517fd7f261a03177e = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_51ba61a82d941ab517fd7f261a03177e.addTo(map_c552b838e939d52b6b1d0e0d602d48a5);
#
#
#             var circle_marker_cfbc477adfe3a13e439df6d0f4aeccc8 = L.circleMarker(
#                 [52.52, 13.405],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;darkblue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;darkblue&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 1.2, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_c552b838e939d52b6b1d0e0d602d48a5);
#
#
#         var popup_40cc327471346ccd192d154981b03736 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_6a49866aa528266ab23bcd4eed9eff90 = $(`&lt;div id=&quot;html_6a49866aa528266ab23bcd4eed9eff90&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Berlin&lt;/div&gt;`)[0];
#                 popup_40cc327471346ccd192d154981b03736.setContent(html_6a49866aa528266ab23bcd4eed9eff90);
#
#
#
#         circle_marker_cfbc477adfe3a13e439df6d0f4aeccc8.bindPopup(popup_40cc327471346ccd192d154981b03736)
#         ;
#
#
#
#
#             var circle_marker_cd445ac04a4e43b5e87b3e0a37551d0b = L.circleMarker(
#                 [48.7775, 9.18],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;darkblue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;darkblue&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 1.2, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_c552b838e939d52b6b1d0e0d602d48a5);
#
#
#         var popup_5a91db2413d2ff5202b137e868ced517 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_a59aeb5e8f2a271289195a5cbf6fb387 = $(`&lt;div id=&quot;html_a59aeb5e8f2a271289195a5cbf6fb387&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Stuttgart&lt;/div&gt;`)[0];
#                 popup_5a91db2413d2ff5202b137e868ced517.setContent(html_a59aeb5e8f2a271289195a5cbf6fb387);
#
#
#
#         circle_marker_cd445ac04a4e43b5e87b3e0a37551d0b.bindPopup(popup_5a91db2413d2ff5202b137e868ced517)
#         ;
#
#
#
#
#             var circle_marker_3000dd77a8db58a59d41d61d5c983ad2 = L.circleMarker(
#                 [48.1375, 11.575],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;darkblue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;darkblue&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 1.2, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_c552b838e939d52b6b1d0e0d602d48a5);
#
#
#         var popup_aba06f71ee04599072a950c113253831 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_c5e6f368e9efb9f01c034625fc61da95 = $(`&lt;div id=&quot;html_c5e6f368e9efb9f01c034625fc61da95&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Munich&lt;/div&gt;`)[0];
#                 popup_aba06f71ee04599072a950c113253831.setContent(html_c5e6f368e9efb9f01c034625fc61da95);
#
#
#
#         circle_marker_3000dd77a8db58a59d41d61d5c983ad2.bindPopup(popup_aba06f71ee04599072a950c113253831)
#         ;
#
#
#
#
#             var circle_marker_dcd945c1d347cadbabd2dc86db23c22c = L.circleMarker(
#                 [53.55, 10.0],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;darkblue&quot;, &quot;dashArray&quot;:
