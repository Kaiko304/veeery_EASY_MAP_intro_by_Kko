# %% [markdown]
# # Very easy intro for data scientists with no clue of geodata but wish for a map.
#
# **About geodata**
#
# there's a lot of theory behind geodata (whole university programms like geodesy etc) because basically
# - some bright spot found out, that the earth is round    =======> (3D-) globe with a geogr. coordinate system   (issue #1: latitude and longitude)
# - some seafaring brothers wanted to use that knowledge  ====> flat (2D-) map with coordinate grid           (issue #2: projection)
# - some researchers obsessed over accuracy   ==============> not a globe but an ellipsoid                  (issue #3: epsg and transformations)
# - now satellites are of the opinion, that the earth is a potato ====> or a geoide ... well, anyway..           (i hesitate to even - hm ...
#
# ... we'll talk about that along the way in easily digestible portions.
#
# **And how to deal with this mess?**
#
# - geometry dtype, shapes (points, lines, polygones), shp-files.
# - maybe we talk a bit about discrete data: vector, raster, (lidar, point cloud).
# - and of course: handling the '#issues'.
#
# **On the bright side:**
#
# geodata is the _MOTHER OF MERGABILITY!_ As soon as you know where something is, you can merge everything with everything ON 'location'. That's called the _'SPATIAL JOIN'_.
#
# Imagine you have the 'height above sea level' and rainfall data. You then can calculate drain rates, flooding hazards and ... a lot of things. Or you get a 'layer' with all roads along with your flooding data. Then you can tell, which roads are passable, which will be passable when water level drops by 20 cm ... and so on. (Let's mention here the strange custom to handle data as 'layers'. You can add to e.g. a topographic 'basemap' additional (data-)layers with infrastructure (roads, cities), with socio-economic data (population, employment) or a layer 'orthophoto' etc.)
#
# And of course, there is the advantage of visualisation by _MAPs_.
#
# **So now,**
#
# let's start with a first map!

# %% [markdown]
# # Make a map with folium library
# documentation: https://python-visualization.github.io/folium/latest/

# %% [markdown]
# **ingredient list**
# - folium.Map()
# - data with latitude and longitude as float
#
# **output**
# - map based on open street map (OSM) = 'basemap'
# - with markers for the data = 'layer'
# - and heatmap for population layer

# %% [markdown]
# ## Import library and data

# %%
# pip install folium
import pandas as pd
import folium

# %%
# load cities data 
# with latitude and longitude as float

data = pd.read_csv("some_cities_data.csv", index_col=None)
data.head(2)
# Out:
#         city  latitude  longitude  country iso2         Bundesland  population
# 0     Berlin   52.5200     13.405  Germany   DE             Berlin   4473101.0
# 1  Stuttgart   48.7775      9.180  Germany   DE  Baden-Württemberg   2787724.0

# %% [markdown]
# This data gives us Cities with location data and other data values for populations.
#
# From that we will first
# - create a topographic basemap using open street map (OSM)
# - then add a data layer with markers for cities
# - and then add a data layer with heatmap for population.
#
# !Vamos!
#
# .

# %% [markdown]
# ## Create Basemap (OSM)

# %%
# create basemap = openstreetmap (OSM)
# with center='middle of Germany' (latitude=51.57, longitude=14.37)

map = folium.Map([51.57, 14.37], zoom_start=6)
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_aa9d2d08e95d4cd528122ac48daf2a32 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_aa9d2d08e95d4cd528122ac48daf2a32&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_aa9d2d08e95d4cd528122ac48daf2a32 = L.map(
#                 &quot;map_aa9d2d08e95d4cd528122ac48daf2a32&quot;,
#                 {
#                     center: [51.57, 14.37],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 6,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_493dfa3e74c081e147e7ac19893196eb = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_493dfa3e74c081e147e7ac19893196eb.addTo(map_aa9d2d08e95d4cd528122ac48daf2a32);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# much too easy, isn't it?
#
#
# .

# %% [markdown]
# ## Add data layer: cities

# %%
# add data layer to basemap
# with markers for cities

for i, row in data.iterrows():
    folium.Marker([row['latitude'], row['longitude']], popup=row['city']
    ).add_to(map)

# %%
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_aa9d2d08e95d4cd528122ac48daf2a32 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_aa9d2d08e95d4cd528122ac48daf2a32&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_aa9d2d08e95d4cd528122ac48daf2a32 = L.map(
#                 &quot;map_aa9d2d08e95d4cd528122ac48daf2a32&quot;,
#                 {
#                     center: [51.57, 14.37],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 6,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_493dfa3e74c081e147e7ac19893196eb = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_493dfa3e74c081e147e7ac19893196eb.addTo(map_aa9d2d08e95d4cd528122ac48daf2a32);
#
#
#             tile_layer_493dfa3e74c081e147e7ac19893196eb.addTo(map_aa9d2d08e95d4cd528122ac48daf2a32);
#
#
#             var marker_a6c9b3f29ac793023f808d27e47c8533 = L.marker(
#                 [52.52, 13.405],
#                 {}
#             ).addTo(map_aa9d2d08e95d4cd528122ac48daf2a32);
#
#
#         var popup_4ee0d96eeb7e53ad74dfee81477ac700 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_e4cd9db90da200f2572f4901a85466b1 = $(`&lt;div id=&quot;html_e4cd9db90da200f2572f4901a85466b1&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Berlin&lt;/div&gt;`)[0];
#                 popup_4ee0d96eeb7e53ad74dfee81477ac700.setContent(html_e4cd9db90da200f2572f4901a85466b1);
#
#
#
#         marker_a6c9b3f29ac793023f808d27e47c8533.bindPopup(popup_4ee0d96eeb7e53ad74dfee81477ac700)
#         ;
#
#
#
#
#             var marker_f9a4579dcd63202cb55376edd6ef4fcc = L.marker(
#                 [48.7775, 9.18],
#                 {}
#             ).addTo(map_aa9d2d08e95d4cd528122ac48daf2a32);
#
#
#         var popup_4491ae48888048efdeb1f1cc5a6b23f7 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_712df75a84920889e9f9f25f460e968f = $(`&lt;div id=&quot;html_712df75a84920889e9f9f25f460e968f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Stuttgart&lt;/div&gt;`)[0];
#                 popup_4491ae48888048efdeb1f1cc5a6b23f7.setContent(html_712df75a84920889e9f9f25f460e968f);
#
#
#
#         marker_f9a4579dcd63202cb55376edd6ef4fcc.bindPopup(popup_4491ae48888048efdeb1f1cc5a6b23f7)
#         ;
#
#
#
#
#             var marker_47c24ab0819bf3eefc49b2f3ba0d67a4 = L.marker(
#                 [48.1375, 11.575],
#                 {}
#             ).addTo(map_aa9d2d08e95d4cd528122ac48daf2a32);
#
#
#         var popup_6b0fcfea16dffb80b00eb093b3bb44c5 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_700fd59ca0cfca17794012777a1a6146 = $(`&lt;div id=&quot;html_700fd59ca0cfca17794012777a1a6146&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Munich&lt;/div&gt;`)[0];
#                 popup_6b0fcfea16dffb80b00eb093b3bb44c5.setContent(html_700fd59ca0cfca17794012777a1a6146);
#
#
#
#         marker_47c24ab0819bf3eefc49b2f3ba0d67a4.bindPopup(popup_6b0fcfea16dffb80b00eb093b3bb44c5)
#         ;
#
#
#
#
#             var marker_a6c1a018d529c6b4e10d565262b4bcbf = L.marker(
#                 [53.55, 10.0],
#                 {}
#             ).addTo(map_aa9d2d08e95d4cd528122ac48daf2a32);
#
#
#         var popup_15d0e1eb111505d7f1162d1ff3ede940 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_67136a40ee3821af243c96ea1542731a = $(`&lt;div id=&quot;html_67136a40ee3821af243c96ea1542731a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Hamburg&lt;/div&gt;`)[0];
#                 popup_15d0e1eb111505d7f1162d1ff3ede940.setContent(html_67136a40ee3821af243c96ea1542731a);
#
#
#
#         marker_a6c1a018d529c6b4e10d565262b4bcbf.bindPopup(popup_15d0e1eb111505d7f1162d1ff3ede940)
#         ;
#
#
#
#
#             var marker_1f831403f69971b8414a9df0277d807c = L.marker(
#                 [50.9364, 6.9528],
#                 {}
#             ).addTo(map_aa9d2d08e95d4cd528122ac48daf2a32);
#
#
#         var popup_9cb5e18a9dd7f2944ca96ab8fbd6fee7 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_524c874af963e94f125070bc181cbde1 = $(`&lt;div id=&quot;html_524c874af963e94f125070bc181cbde1&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Cologne&lt;/div&gt;`)[0];
#                 popup_9cb5e18a9dd7f2944ca96ab8fbd6fee7.setContent(html_524c874af963e94f125070bc181cbde1);
#
#
#
#         marker_1f831403f69971b8414a9df0277d807c.bindPopup(popup_9cb5e18a9dd7f2944ca96ab8fbd6fee7)
#         ;
#
#
#
#
#             var marker_a2f46d09fd8773a0c29c151f67bfd069 = L.marker(
#                 [50.1106, 8.6822],
#                 {}
#             ).addTo(map_aa9

# %% [markdown]
# You just made your first map, congratulations!
#
#
#
#
# .

# %% [markdown]
# **Change marker symbols to 'CircleMarkers'**

# %%
# create basemap OSM
map = folium.Map([51.57, 14.37], zoom_start=6)

# add data layer cities
for i, row in data.iterrows():
    folium.CircleMarker([row['latitude'], row['longitude']], popup=row['city'], radius=5, color='green', fill=True, fill_color='black'
    ).add_to(map)
    
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_3bdf78cc02a0ed5bec39264010009ee2 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_3bdf78cc02a0ed5bec39264010009ee2&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_3bdf78cc02a0ed5bec39264010009ee2 = L.map(
#                 &quot;map_3bdf78cc02a0ed5bec39264010009ee2&quot;,
#                 {
#                     center: [51.57, 14.37],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 6,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_7ac6924413763bb91b7504df202eefd3 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_7ac6924413763bb91b7504df202eefd3.addTo(map_3bdf78cc02a0ed5bec39264010009ee2);
#
#
#             var circle_marker_e26ac8453e6f595d5538657099c52a8b = L.circleMarker(
#                 [52.52, 13.405],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;green&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;black&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 5, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_3bdf78cc02a0ed5bec39264010009ee2);
#
#
#         var popup_2450ffdf0b4f378c838b3043ad971dc1 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_40dcdad5de8e9c1bfbde405033aad91b = $(`&lt;div id=&quot;html_40dcdad5de8e9c1bfbde405033aad91b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Berlin&lt;/div&gt;`)[0];
#                 popup_2450ffdf0b4f378c838b3043ad971dc1.setContent(html_40dcdad5de8e9c1bfbde405033aad91b);
#
#
#
#         circle_marker_e26ac8453e6f595d5538657099c52a8b.bindPopup(popup_2450ffdf0b4f378c838b3043ad971dc1)
#         ;
#
#
#
#
#             var circle_marker_bc4b5d2d4d92573c6bc9115b9b6680a8 = L.circleMarker(
#                 [48.7775, 9.18],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;green&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;black&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 5, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_3bdf78cc02a0ed5bec39264010009ee2);
#
#
#         var popup_0086a40b2d6320c1f17bf9826602cfe3 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_dbfeb41c9c59151da5a5cb7ca4a1e032 = $(`&lt;div id=&quot;html_dbfeb41c9c59151da5a5cb7ca4a1e032&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Stuttgart&lt;/div&gt;`)[0];
#                 popup_0086a40b2d6320c1f17bf9826602cfe3.setContent(html_dbfeb41c9c59151da5a5cb7ca4a1e032);
#
#
#
#         circle_marker_bc4b5d2d4d92573c6bc9115b9b6680a8.bindPopup(popup_0086a40b2d6320c1f17bf9826602cfe3)
#         ;
#
#
#
#
#             var circle_marker_55c7f16f3a671349eb5ce1a7dd071660 = L.circleMarker(
#                 [48.1375, 11.575],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;green&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;black&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 5, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_3bdf78cc02a0ed5bec39264010009ee2);
#
#
#         var popup_2e6d66440b2fa57243a77538c97e4671 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_85e2f2a0116980f1108467a33ada08c9 = $(`&lt;div id=&quot;html_85e2f2a0116980f1108467a33ada08c9&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Munich&lt;/div&gt;`)[0];
#                 popup_2e6d66440b2fa57243a77538c97e4671.setContent(html_85e2f2a0116980f1108467a33ada08c9);
#
#
#
#         circle_marker_55c7f16f3a671349eb5ce1a7dd071660.bindPopup(popup_2e6d66440b2fa57243a77538c97e4671)
#         ;
#
#
#
#
#             var circle_marker_32a14c38be56984aa041c6273cf565ae = L.circleMarker(
#                 [53.55, 10.0],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;green&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;black&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &q

# %% [markdown]
# ## Add heatmap layer: population

# %%
from folium.plugins import HeatMap

# prepate heatmap_data
hm_data = []
for i, row in data.iterrows():
    hm_data.append([row['latitude'], row['longitude'], row['population']])

# add heatmap layer to map
HeatMap(hm_data
    ).add_to(map)
    
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_3bdf78cc02a0ed5bec39264010009ee2 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium@main/folium/templates/leaflet_heat.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_3bdf78cc02a0ed5bec39264010009ee2&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_3bdf78cc02a0ed5bec39264010009ee2 = L.map(
#                 &quot;map_3bdf78cc02a0ed5bec39264010009ee2&quot;,
#                 {
#                     center: [51.57, 14.37],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 6,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_7ac6924413763bb91b7504df202eefd3 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_7ac6924413763bb91b7504df202eefd3.addTo(map_3bdf78cc02a0ed5bec39264010009ee2);
#
#
#             var circle_marker_e26ac8453e6f595d5538657099c52a8b = L.circleMarker(
#                 [52.52, 13.405],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;green&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;black&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 5, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_3bdf78cc02a0ed5bec39264010009ee2);
#
#
#         var popup_2450ffdf0b4f378c838b3043ad971dc1 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_40dcdad5de8e9c1bfbde405033aad91b = $(`&lt;div id=&quot;html_40dcdad5de8e9c1bfbde405033aad91b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Berlin&lt;/div&gt;`)[0];
#                 popup_2450ffdf0b4f378c838b3043ad971dc1.setContent(html_40dcdad5de8e9c1bfbde405033aad91b);
#
#
#
#         circle_marker_e26ac8453e6f595d5538657099c52a8b.bindPopup(popup_2450ffdf0b4f378c838b3043ad971dc1)
#         ;
#
#
#
#
#             var circle_marker_bc4b5d2d4d92573c6bc9115b9b6680a8 = L.circleMarker(
#                 [48.7775, 9.18],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;green&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;black&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 5, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_3bdf78cc02a0ed5bec39264010009ee2);
#
#
#         var popup_0086a40b2d6320c1f17bf9826602cfe3 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_dbfeb41c9c59151da5a5cb7ca4a1e032 = $(`&lt;div id=&quot;html_dbfeb41c9c59151da5a5cb7ca4a1e032&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Stuttgart&lt;/div&gt;`)[0];
#                 popup_0086a40b2d6320c1f17bf9826602cfe3.setContent(html_dbfeb41c9c59151da5a5cb7ca4a1e032);
#
#
#
#         circle_marker_bc4b5d2d4d92573c6bc9115b9b6680a8.bindPopup(popup_0086a40b2d6320c1f17bf9826602cfe3)
#         ;
#
#
#
#
#             var circle_marker_55c7f16f3a671349eb5ce1a7dd071660 = L.circleMarker(
#                 [48.1375, 11.575],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;green&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;black&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 5, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_3bdf78cc02a0ed5bec39264010009ee2);
#
#
#         var popup_2e6d66440b2fa57243a77538c97e4671 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_85e2f2a0116980f1108467a33ada08c9 = $(`&lt;div id=&quot;html_85e2f2a0116980f1108467a33ada08c9&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Munich&lt;/div&gt;`)[0];
#                 popup_2e6d66440b2fa57243a77538c97e4671.setContent(html_85e2f2a0116980f1108467a33ada08c9);
#
#
#
#         circle_marker_55c7f16f3a671349eb5ce1a7dd071660.bindPopup(popup_2e6d66440b2fa57243a77538c97e4671)
#         ;
#
#
#
#
#             var circle_marker_32a14c38be56984aa041c6273cf565ae = L.circleMarker(
#                 [53.55, 10.0],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;green&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;:

# %% [markdown]
# Well done! You've already created a basemap with two layers :)
#
#
#
# .

# %% [markdown]
# # _Concessions_
#
# _I know i promised more in the introduction, and i intend to continue here with geopandas and geometry format._
#
# _But -sadly- it's time for bed now._
#
# _You've made your first map! So stopp nagging :)_
#
# _Good n8 and CU soon!_

# %% [markdown]
# # Conclusion as send off for the night -haha-

# %%
def folium_map(data):
    import pandas as pd
    import folium
    from folium.plugins import HeatMap

    # create basemap OSM
    map = folium.Map([51.57, 14.37], zoom_start=6)

    # add data layer cities
    for i, row in data.iterrows():
        folium.CircleMarker([row['latitude'], row['longitude']], popup=row['city'], radius=1.2, color='darkblue'
        ).add_to(map)

    # prepate heatmap_data
    hm_data = []
    for i, row in data.iterrows():
        hm_data.append([row['latitude'], row['longitude'], row['population']])

    # add heatmap layer population
    HeatMap(hm_data
        ).add_to(map)
    return map

# %%
# load data with latitude and lognitude as float
data = pd.read_csv("some_cities_data.csv", index_col=None)

# call folium_map
map = folium_map(data)
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_1d196cb34909d1db7ae7c20778caa466 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium@main/folium/templates/leaflet_heat.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_1d196cb34909d1db7ae7c20778caa466&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_1d196cb34909d1db7ae7c20778caa466 = L.map(
#                 &quot;map_1d196cb34909d1db7ae7c20778caa466&quot;,
#                 {
#                     center: [51.57, 14.37],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 6,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_06f04ecdd0d6211cac5b61aac6ae520c = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_06f04ecdd0d6211cac5b61aac6ae520c.addTo(map_1d196cb34909d1db7ae7c20778caa466);
#
#
#             var circle_marker_88ce4ddf3d702fb0ce2a57ec1866bb30 = L.circleMarker(
#                 [52.52, 13.405],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;darkblue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;darkblue&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 1.2, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_1d196cb34909d1db7ae7c20778caa466);
#
#
#         var popup_c7628cda08b70b00fd1210fc13576b09 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_3bf0d409a390ee78e1af292dd7fd7854 = $(`&lt;div id=&quot;html_3bf0d409a390ee78e1af292dd7fd7854&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Berlin&lt;/div&gt;`)[0];
#                 popup_c7628cda08b70b00fd1210fc13576b09.setContent(html_3bf0d409a390ee78e1af292dd7fd7854);
#
#
#
#         circle_marker_88ce4ddf3d702fb0ce2a57ec1866bb30.bindPopup(popup_c7628cda08b70b00fd1210fc13576b09)
#         ;
#
#
#
#
#             var circle_marker_a6b4e845acef36c0cc104f0137c5792a = L.circleMarker(
#                 [48.7775, 9.18],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;darkblue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;darkblue&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 1.2, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_1d196cb34909d1db7ae7c20778caa466);
#
#
#         var popup_d561fa23764984a714d49a7a9ea2b189 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_52423d6e1582f35fc6ed79d8d65b72b6 = $(`&lt;div id=&quot;html_52423d6e1582f35fc6ed79d8d65b72b6&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Stuttgart&lt;/div&gt;`)[0];
#                 popup_d561fa23764984a714d49a7a9ea2b189.setContent(html_52423d6e1582f35fc6ed79d8d65b72b6);
#
#
#
#         circle_marker_a6b4e845acef36c0cc104f0137c5792a.bindPopup(popup_d561fa23764984a714d49a7a9ea2b189)
#         ;
#
#
#
#
#             var circle_marker_4a3094d4973ac1697301e22a6af8a240 = L.circleMarker(
#                 [48.1375, 11.575],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;darkblue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;darkblue&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 1.2, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_1d196cb34909d1db7ae7c20778caa466);
#
#
#         var popup_c41182026ffa53883766d1124bb37c77 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_767672ee40834a8431fbf2d416d5e04a = $(`&lt;div id=&quot;html_767672ee40834a8431fbf2d416d5e04a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Munich&lt;/div&gt;`)[0];
#                 popup_c41182026ffa53883766d1124bb37c77.setContent(html_767672ee40834a8431fbf2d416d5e04a);
#
#
#
#         circle_marker_4a3094d4973ac1697301e22a6af8a240.bindPopup(popup_c41182026ffa53883766d1124bb37c77)
#         ;
#
#
#
#
#             var circle_marker_c3eefc7cf12e8e2d4119db22b270ba40 = L.circleMarker(
#                 [53.55, 10.0],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;darkblue&quot;, &quot;dashArray&quot;:

# %%
map.save('map_cities_population.html')
