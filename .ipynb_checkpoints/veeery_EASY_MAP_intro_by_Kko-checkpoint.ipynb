# %% [markdown]
# # Very easy intro for data scientists with no clue of geodata but wish for a map.
#
# **About geodata**
#
# there's a lot of theory behind geodata (whole university programms like geodesy etc) because basically
# - some bright spot found out, that the earth is round    =======> (3D-) globe with a geogr. coordinate system   (issue #1: latitude and longitude)
# - some seafaring brothers wanted to use that knowledge  ====> flat (2D-) map with coordinate grid           (issue #2: projection)
# - some researchers obsessed over accuracy   ==============> not a globe but an ellipsoid                  (issue #3: epsg and transformations)
# - now satellites are of the opinion, that the earth is a potato ====> or a geoide ... well, anyway..           (i hesitate to even - hm ...
#
# ... we'll talk about that along the way in easily digestible portions.
#
# **And how to deal with this mess?**
#
# - geometry dtype, shapes (points, lines, polygones), shp-files.
# - maybe we talk a bit about discrete data: vector, raster, (lidar, point cloud).
# - and of course: handling the '#issues'.
#
# **On the bright side:**
#
# geodata is the _MOTHER OF MERGABILITY!_ As soon as you know where something is, you can merge everything with everything ON 'location'. That's called the _'SPATIAL JOIN'_.
#
# Imagine you have the 'height above sea level' and rainfall data. You then can calculate drain rates, flooding hazards and ... a lot of things. Or you get a 'layer' with all roads along with your flooding data. Then you can tell, which roads are passable, which will be passable when water level drops by 20 cm ... and so on. (Let's mention here the strange custom to handle data as 'layers'. You can add to e.g. a topographic 'basemap' additional (data-)layers with infrastructure (roads, cities), with socio-economic data (population, employment) or a layer 'orthophoto' etc.)
#
# And of course, there is the advantage of visualisation by _MAPs_.
#
# **So now,**
#
# let's start with a first map!

# %% [markdown]
# # Make a map with folium library
# documentation: https://python-visualization.github.io/folium/latest/

# %% [markdown]
# **ingredient list**
# - folium.Map()
# - data with latitude and longitude as float
#
# **output**
# - map based on open street map (OSM) = 'basemap'
# - with markers for the data = 'layer'
# - and heatmap for population layer

# %% [markdown]
# ## Import library and data

# %%
# pip install folium
import pandas as pd
import folium

# %%
# load cities data 
# with latitude and longitude as float

data = pd.read_csv("some_cities_data.csv", index_col=None)
data.head(2)
# Out:
#         city  latitude  longitude  country iso2         Bundesland  population
# 0     Berlin   52.5200     13.405  Germany   DE             Berlin   4473101.0
# 1  Stuttgart   48.7775      9.180  Germany   DE  Baden-Württemberg   2787724.0

# %% [markdown]
# This data gives us Cities with location data and other data values for populations.
#
# From that we will first
# - create a topographic basemap using open street map (OSM)
# - then add a data layer with markers for cities
# - and then add a data layer with heatmap for population.
#
# !Vamos!
#
# .

# %% [markdown]
# ## Create Basemap (OSM)

# %%
# create basemap = openstreetmap (OSM)
# with center='Germany' (latitude=51.57, longitude=14.37)

map = folium.Map([51.57, 14.37], zoom_start=6)
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_4e3498fd433d7644413e5259650f111f {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_4e3498fd433d7644413e5259650f111f&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_4e3498fd433d7644413e5259650f111f = L.map(
#                 &quot;map_4e3498fd433d7644413e5259650f111f&quot;,
#                 {
#                     center: [51.57, 14.37],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 6,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_f69689c6f58c475627ee14fa0bcbd315 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_f69689c6f58c475627ee14fa0bcbd315.addTo(map_4e3498fd433d7644413e5259650f111f);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# much too easy, isn't it?
#
#
# .

# %% [markdown]
# ## Add marker layer: cities

# %%
# add data layer to basemap
# with markers for cities

for i, row in data.iterrows():
    folium.Marker([row['latitude'], row['longitude']], popup=row['city']
    ).add_to(map)

# %%
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_4e3498fd433d7644413e5259650f111f {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_4e3498fd433d7644413e5259650f111f&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_4e3498fd433d7644413e5259650f111f = L.map(
#                 &quot;map_4e3498fd433d7644413e5259650f111f&quot;,
#                 {
#                     center: [51.57, 14.37],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 6,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_f69689c6f58c475627ee14fa0bcbd315 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_f69689c6f58c475627ee14fa0bcbd315.addTo(map_4e3498fd433d7644413e5259650f111f);
#
#
#             tile_layer_f69689c6f58c475627ee14fa0bcbd315.addTo(map_4e3498fd433d7644413e5259650f111f);
#
#
#             var marker_1847b9d14d2a6eaf819ed257270b8a0a = L.marker(
#                 [52.52, 13.405],
#                 {}
#             ).addTo(map_4e3498fd433d7644413e5259650f111f);
#
#
#         var popup_b40ef24066075f181b3838adeb39c811 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_756a154719f09cc97284ec2503e43221 = $(`&lt;div id=&quot;html_756a154719f09cc97284ec2503e43221&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Berlin&lt;/div&gt;`)[0];
#                 popup_b40ef24066075f181b3838adeb39c811.setContent(html_756a154719f09cc97284ec2503e43221);
#
#
#
#         marker_1847b9d14d2a6eaf819ed257270b8a0a.bindPopup(popup_b40ef24066075f181b3838adeb39c811)
#         ;
#
#
#
#
#             var marker_0089dbb779565fc3b659df22874db045 = L.marker(
#                 [48.7775, 9.18],
#                 {}
#             ).addTo(map_4e3498fd433d7644413e5259650f111f);
#
#
#         var popup_217a4c8cad9c24d9b58e74d667c7a7e0 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_6d37a8fab547411e45d6652a5f8216b4 = $(`&lt;div id=&quot;html_6d37a8fab547411e45d6652a5f8216b4&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Stuttgart&lt;/div&gt;`)[0];
#                 popup_217a4c8cad9c24d9b58e74d667c7a7e0.setContent(html_6d37a8fab547411e45d6652a5f8216b4);
#
#
#
#         marker_0089dbb779565fc3b659df22874db045.bindPopup(popup_217a4c8cad9c24d9b58e74d667c7a7e0)
#         ;
#
#
#
#
#             var marker_acae3cd04c8e2c5fe2b4f244cc6a4a4c = L.marker(
#                 [48.1375, 11.575],
#                 {}
#             ).addTo(map_4e3498fd433d7644413e5259650f111f);
#
#
#         var popup_0ffa0342482ecbb642d06a63c4ccc62b = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_92208ecf9d545bd0831d381437f455d9 = $(`&lt;div id=&quot;html_92208ecf9d545bd0831d381437f455d9&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Munich&lt;/div&gt;`)[0];
#                 popup_0ffa0342482ecbb642d06a63c4ccc62b.setContent(html_92208ecf9d545bd0831d381437f455d9);
#
#
#
#         marker_acae3cd04c8e2c5fe2b4f244cc6a4a4c.bindPopup(popup_0ffa0342482ecbb642d06a63c4ccc62b)
#         ;
#
#
#
#
#             var marker_2d9b5ec55df4661234319e9a86a28685 = L.marker(
#                 [53.55, 10.0],
#                 {}
#             ).addTo(map_4e3498fd433d7644413e5259650f111f);
#
#
#         var popup_f4ac1928a8a48246abb6add8fdfb58cc = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_d9955a29b0f56e5ad40cc7656e7111f8 = $(`&lt;div id=&quot;html_d9955a29b0f56e5ad40cc7656e7111f8&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Hamburg&lt;/div&gt;`)[0];
#                 popup_f4ac1928a8a48246abb6add8fdfb58cc.setContent(html_d9955a29b0f56e5ad40cc7656e7111f8);
#
#
#
#         marker_2d9b5ec55df4661234319e9a86a28685.bindPopup(popup_f4ac1928a8a48246abb6add8fdfb58cc)
#         ;
#
#
#
#
#             var marker_e0edf389bf3d5e67222f377149907f39 = L.marker(
#                 [50.9364, 6.9528],
#                 {}
#             ).addTo(map_4e3498fd433d7644413e5259650f111f);
#
#
#         var popup_12a732e33eb1178a5ccf910d5b6af653 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_34949755f9fd6cddcc2340c25fef86fb = $(`&lt;div id=&quot;html_34949755f9fd6cddcc2340c25fef86fb&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Cologne&lt;/div&gt;`)[0];
#                 popup_12a732e33eb1178a5ccf910d5b6af653.setContent(html_34949755f9fd6cddcc2340c25fef86fb);
#
#
#
#         marker_e0edf389bf3d5e67222f377149907f39.bindPopup(popup_12a732e33eb1178a5ccf910d5b6af653)
#         ;
#
#
#
#
#             var marker_8a361e09c2f7dc4e3e347f0309760221 = L.marker(
#                 [50.1106, 8.6822],
#                 {}
#             ).addTo(map_4e3

# %% [markdown]
# You just made your first map, congratulations!
#
#
#
#
# .

# %% [markdown]
# **Change marker symbols to 'CircleMarkers'**

# %%
# create basemap OSM
map = folium.Map([51.57, 14.37], zoom_start=6)

# add CircleMarker layer
for i, row in data.iterrows():
    folium.CircleMarker([row['latitude'], row['longitude']], popup=row['city'], radius=5, color='green', fill=True, fill_color='black'
    ).add_to(map)
    
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_3bc1366587b304bbf2362f074c73aff1 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_3bc1366587b304bbf2362f074c73aff1&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_3bc1366587b304bbf2362f074c73aff1 = L.map(
#                 &quot;map_3bc1366587b304bbf2362f074c73aff1&quot;,
#                 {
#                     center: [51.57, 14.37],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 6,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_4e237be910163e05e1e83686f8c45453 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_4e237be910163e05e1e83686f8c45453.addTo(map_3bc1366587b304bbf2362f074c73aff1);
#
#
#             var circle_marker_7f41d74a83b2bc70ae7410a18747a6ab = L.circleMarker(
#                 [52.52, 13.405],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;green&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;black&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 5, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_3bc1366587b304bbf2362f074c73aff1);
#
#
#         var popup_f6a1039f30300dc35ebce7dcf0d17af5 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_38c7e7d812bb70365b1c7d7a0e641449 = $(`&lt;div id=&quot;html_38c7e7d812bb70365b1c7d7a0e641449&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Berlin&lt;/div&gt;`)[0];
#                 popup_f6a1039f30300dc35ebce7dcf0d17af5.setContent(html_38c7e7d812bb70365b1c7d7a0e641449);
#
#
#
#         circle_marker_7f41d74a83b2bc70ae7410a18747a6ab.bindPopup(popup_f6a1039f30300dc35ebce7dcf0d17af5)
#         ;
#
#
#
#
#             var circle_marker_ecdca63fa3af7b09a91cc8b366af7599 = L.circleMarker(
#                 [48.7775, 9.18],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;green&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;black&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 5, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_3bc1366587b304bbf2362f074c73aff1);
#
#
#         var popup_4c765d3a3efbf9748ce7455b4bdaf3c9 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_3d654ce918eccec64dee2817d227ffe5 = $(`&lt;div id=&quot;html_3d654ce918eccec64dee2817d227ffe5&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Stuttgart&lt;/div&gt;`)[0];
#                 popup_4c765d3a3efbf9748ce7455b4bdaf3c9.setContent(html_3d654ce918eccec64dee2817d227ffe5);
#
#
#
#         circle_marker_ecdca63fa3af7b09a91cc8b366af7599.bindPopup(popup_4c765d3a3efbf9748ce7455b4bdaf3c9)
#         ;
#
#
#
#
#             var circle_marker_b52635b9a654384b02b6cb28bbd60893 = L.circleMarker(
#                 [48.1375, 11.575],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;green&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;black&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 5, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_3bc1366587b304bbf2362f074c73aff1);
#
#
#         var popup_c087314fa3c1bd489f62096bcfebbd50 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_9356ae7dfee6eff2047f7796921bfb8d = $(`&lt;div id=&quot;html_9356ae7dfee6eff2047f7796921bfb8d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Munich&lt;/div&gt;`)[0];
#                 popup_c087314fa3c1bd489f62096bcfebbd50.setContent(html_9356ae7dfee6eff2047f7796921bfb8d);
#
#
#
#         circle_marker_b52635b9a654384b02b6cb28bbd60893.bindPopup(popup_c087314fa3c1bd489f62096bcfebbd50)
#         ;
#
#
#
#
#             var circle_marker_30ecb17902e40ce0238222641f15c00c = L.circleMarker(
#                 [53.55, 10.0],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;green&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;black&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &q

# %% [markdown]
# ## Add heatmap layer: population

# %%
from folium.plugins import HeatMap

# prepate heatmap_data
hm_data = []
for i, row in data.iterrows():
    hm_data.append([row['latitude'], row['longitude'], row['population']])

# add heatmap layer to map
HeatMap(hm_data
    ).add_to(map)
    
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_3bc1366587b304bbf2362f074c73aff1 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium@main/folium/templates/leaflet_heat.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_3bc1366587b304bbf2362f074c73aff1&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_3bc1366587b304bbf2362f074c73aff1 = L.map(
#                 &quot;map_3bc1366587b304bbf2362f074c73aff1&quot;,
#                 {
#                     center: [51.57, 14.37],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 6,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_4e237be910163e05e1e83686f8c45453 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_4e237be910163e05e1e83686f8c45453.addTo(map_3bc1366587b304bbf2362f074c73aff1);
#
#
#             var circle_marker_7f41d74a83b2bc70ae7410a18747a6ab = L.circleMarker(
#                 [52.52, 13.405],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;green&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;black&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 5, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_3bc1366587b304bbf2362f074c73aff1);
#
#
#         var popup_f6a1039f30300dc35ebce7dcf0d17af5 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_38c7e7d812bb70365b1c7d7a0e641449 = $(`&lt;div id=&quot;html_38c7e7d812bb70365b1c7d7a0e641449&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Berlin&lt;/div&gt;`)[0];
#                 popup_f6a1039f30300dc35ebce7dcf0d17af5.setContent(html_38c7e7d812bb70365b1c7d7a0e641449);
#
#
#
#         circle_marker_7f41d74a83b2bc70ae7410a18747a6ab.bindPopup(popup_f6a1039f30300dc35ebce7dcf0d17af5)
#         ;
#
#
#
#
#             var circle_marker_ecdca63fa3af7b09a91cc8b366af7599 = L.circleMarker(
#                 [48.7775, 9.18],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;green&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;black&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 5, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_3bc1366587b304bbf2362f074c73aff1);
#
#
#         var popup_4c765d3a3efbf9748ce7455b4bdaf3c9 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_3d654ce918eccec64dee2817d227ffe5 = $(`&lt;div id=&quot;html_3d654ce918eccec64dee2817d227ffe5&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Stuttgart&lt;/div&gt;`)[0];
#                 popup_4c765d3a3efbf9748ce7455b4bdaf3c9.setContent(html_3d654ce918eccec64dee2817d227ffe5);
#
#
#
#         circle_marker_ecdca63fa3af7b09a91cc8b366af7599.bindPopup(popup_4c765d3a3efbf9748ce7455b4bdaf3c9)
#         ;
#
#
#
#
#             var circle_marker_b52635b9a654384b02b6cb28bbd60893 = L.circleMarker(
#                 [48.1375, 11.575],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;green&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;black&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 5, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_3bc1366587b304bbf2362f074c73aff1);
#
#
#         var popup_c087314fa3c1bd489f62096bcfebbd50 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_9356ae7dfee6eff2047f7796921bfb8d = $(`&lt;div id=&quot;html_9356ae7dfee6eff2047f7796921bfb8d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Munich&lt;/div&gt;`)[0];
#                 popup_c087314fa3c1bd489f62096bcfebbd50.setContent(html_9356ae7dfee6eff2047f7796921bfb8d);
#
#
#
#         circle_marker_b52635b9a654384b02b6cb28bbd60893.bindPopup(popup_c087314fa3c1bd489f62096bcfebbd50)
#         ;
#
#
#
#
#             var circle_marker_30ecb17902e40ce0238222641f15c00c = L.circleMarker(
#                 [53.55, 10.0],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;green&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;:

# %% [markdown]
# Well done! You've already created a basemap with two layers :)
#
#
#
# .

# %% [markdown]
# # _Concessions_
#
# _I know i promised more in the introduction, and i intend to continue here with geopandas and geometry format._
#
# _But -sadly- it's time for bed now._
#
# _You've made your first map! So stopp nagging :)_
#
# _Good n8 and CU soon!_

# %% [markdown]
# # Summary as send off for the night -haha-

# %%
def folium_map(data):
    import pandas as pd
    import folium
    from folium.plugins import HeatMap

    # create basemap OSM
    map = folium.Map([51.57, 14.37], zoom_start=6)

    # add marker layer 'cities'
    for i, row in data.iterrows():
        folium.CircleMarker([row['latitude'], row['longitude']], popup=row['city'], radius=1.2, color='darkblue'
        ).add_to(map)

    # prepate heatmap_data
    hm_data = []
    for i, row in data.iterrows():
        hm_data.append([row['latitude'], row['longitude'], row['population']])

    # add heatmap layer 'population'
    HeatMap(hm_data
        ).add_to(map)
    return map

# %%
# load data with latitude and lognitude as float
data = pd.read_csv("some_cities_data.csv", index_col=None)

# call folium_map
map = folium_map(data)
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_432ede41f8ded476228a419334bd0719 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium@main/folium/templates/leaflet_heat.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_432ede41f8ded476228a419334bd0719&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_432ede41f8ded476228a419334bd0719 = L.map(
#                 &quot;map_432ede41f8ded476228a419334bd0719&quot;,
#                 {
#                     center: [51.57, 14.37],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 6,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_6e55442ce8cb65ec51c03936f3698563 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_6e55442ce8cb65ec51c03936f3698563.addTo(map_432ede41f8ded476228a419334bd0719);
#
#
#             var circle_marker_30ad943a9a4c7724eb25a495d57d58d2 = L.circleMarker(
#                 [52.52, 13.405],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;darkblue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;darkblue&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 1.2, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_432ede41f8ded476228a419334bd0719);
#
#
#         var popup_a13eedd2186ee77a62551c223287812a = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_465d66b655129d2d160f3048c197a38f = $(`&lt;div id=&quot;html_465d66b655129d2d160f3048c197a38f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Berlin&lt;/div&gt;`)[0];
#                 popup_a13eedd2186ee77a62551c223287812a.setContent(html_465d66b655129d2d160f3048c197a38f);
#
#
#
#         circle_marker_30ad943a9a4c7724eb25a495d57d58d2.bindPopup(popup_a13eedd2186ee77a62551c223287812a)
#         ;
#
#
#
#
#             var circle_marker_1d58a8c4045d9fd3cfdffd47d7eab3b6 = L.circleMarker(
#                 [48.7775, 9.18],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;darkblue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;darkblue&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 1.2, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_432ede41f8ded476228a419334bd0719);
#
#
#         var popup_b82097ad13273c0d1ac9f692f4fce68c = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_12d647b42b4419f0f7346a39328a16b1 = $(`&lt;div id=&quot;html_12d647b42b4419f0f7346a39328a16b1&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Stuttgart&lt;/div&gt;`)[0];
#                 popup_b82097ad13273c0d1ac9f692f4fce68c.setContent(html_12d647b42b4419f0f7346a39328a16b1);
#
#
#
#         circle_marker_1d58a8c4045d9fd3cfdffd47d7eab3b6.bindPopup(popup_b82097ad13273c0d1ac9f692f4fce68c)
#         ;
#
#
#
#
#             var circle_marker_a2f7109a0216ff4b56c77eff91a0b0ee = L.circleMarker(
#                 [48.1375, 11.575],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;darkblue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;darkblue&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 1.2, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_432ede41f8ded476228a419334bd0719);
#
#
#         var popup_144e33272dc2817fe158b29e7d29b6b6 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_608ab155bba65b0f5632120d6eade99b = $(`&lt;div id=&quot;html_608ab155bba65b0f5632120d6eade99b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Munich&lt;/div&gt;`)[0];
#                 popup_144e33272dc2817fe158b29e7d29b6b6.setContent(html_608ab155bba65b0f5632120d6eade99b);
#
#
#
#         circle_marker_a2f7109a0216ff4b56c77eff91a0b0ee.bindPopup(popup_144e33272dc2817fe158b29e7d29b6b6)
#         ;
#
#
#
#
#             var circle_marker_eeaaf583102a7fad8b999b3af86cde47 = L.circleMarker(
#                 [53.55, 10.0],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;darkblue&quot;, &quot;dashArray&quot;:

# %%
map.save('map_cities_population.html')
