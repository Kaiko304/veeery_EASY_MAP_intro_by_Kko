# %% [markdown]
# # Very easy intro for data scientists with no clue of geodata but wish for a map.
#
# **About geodata**
#
# there's a lot of theory behind geodata (whole university programms like geodesy etc) because basically
# - some bright spot found out, that the earth is round    =======> (3D-) globe with a geogr. coordinate system   (issue #1: latitude and longitude)
# - some seafearing brothers wanted to use that knowledge  ====> flat (2D-) map with coordinate grid           (issue #2: projection)
# - some researchers obsessed over accuracy   ==============> not a globe but an ellipsoid                  (issue #3: epsg and transformations)
# - now satellites are of the opinion, that the earth is a potato ====> or a geoide ... well, anyway..           (i hesitate to even - hm ...
#
# ... we'll talk about that along the way in easily digestible portions.
#
# **And how to deal with this mess?**
#
# - geometry dtype, shapes (points, lines, polygones), shp-files.
# - maybe we talk a bit about discrete data: vector, raster, (lidar, point cloud).
# - and of course: handling the '#issues'.
#
# **On the bright side:**
#
# geodata is the _MOTHER OF MERGABILITY!_ As soon as you know where something is, you can merge everything with everything ON 'location'. That's called the _'SPATIAL JOIN'_.
#
# Imagine you have the 'height above sea level' and rainfall data. You then can calculate drain rates, flooding hazards and ... a lot of things. Or you get a 'layer' with all roads along with your flooding data. Then you can tell, which roads are passable, which will be passable when water level drops by 20 cm ... and so on. (Let's mention here the strange custom to handle data as 'layers'. You can add to e.g. a topographic 'basemap' additional (data-)layers with infrastructure (roads, cities), with socio-economic data (population, employment) or a layer 'orthophoto' etc.)
#
# And of course, there is the advantage of visualisation by _MAPs_.
#
# **So now,**
#
# let's start with a first map!

# %% [markdown]
# # Make a map with folium library
# documentation: https://python-visualization.github.io/folium/latest/

# %% [markdown]
# **ingredient list**
# - folium.Map()
# - data with latitude and longitude as float
#
# **output**
# - map based on open street map (OSM) = 'basemap'
# - with markers for the data = 'layer'
# - and heatmap for population layer

# %% [markdown]
# ## Import library and data

# %%
# pip install folium
import pandas as pd
import folium

# %%
# load cities data 
# with latitude and longitude as float

data = pd.read_csv("some_cities_data.csv", index_col=None)
data.head(2)
# Out:
#         city  latitude  longitude  country iso2         Bundesland  population
# 0     Berlin   52.5200     13.405  Germany   DE             Berlin   4473101.0
# 1  Stuttgart   48.7775      9.180  Germany   DE  Baden-Württemberg   2787724.0

# %% [markdown]
# This data gives us Cities with location data and other data values for populations.
#
# From that we will first
# - create a topographic basemap using open street map (OSM)
# - then add a data layer with markers for cities
# - and then add a data layer with heatmap for population.
#
# !Vamos!
#
# .

# %% [markdown]
# ## Create Basemap (OSM)

# %%
# create basemap = openstreetmap (OSM)
# with center='middle of Germany' (latitude=51.57, longitude=14.37)

map = folium.Map([51.57, 14.37], zoom_start=6)
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_9c579fe233e9b5e358e2be61c855773b {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_9c579fe233e9b5e358e2be61c855773b&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_9c579fe233e9b5e358e2be61c855773b = L.map(
#                 &quot;map_9c579fe233e9b5e358e2be61c855773b&quot;,
#                 {
#                     center: [51.57, 14.37],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 6,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_2aba54ea2d78fa708fb605b2461bf5f0 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_2aba54ea2d78fa708fb605b2461bf5f0.addTo(map_9c579fe233e9b5e358e2be61c855773b);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# much too easy, isn't it?
#
#
# .

# %% [markdown]
# ## Add data layer: cities

# %%
# add data layer to basemap
# with markers for cities

for i, row in data.iterrows():
    folium.Marker([row['latitude'], row['longitude']], popup=row['city']
    ).add_to(map)

# %%
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_9c579fe233e9b5e358e2be61c855773b {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_9c579fe233e9b5e358e2be61c855773b&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_9c579fe233e9b5e358e2be61c855773b = L.map(
#                 &quot;map_9c579fe233e9b5e358e2be61c855773b&quot;,
#                 {
#                     center: [51.57, 14.37],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 6,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_2aba54ea2d78fa708fb605b2461bf5f0 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_2aba54ea2d78fa708fb605b2461bf5f0.addTo(map_9c579fe233e9b5e358e2be61c855773b);
#
#
#             tile_layer_2aba54ea2d78fa708fb605b2461bf5f0.addTo(map_9c579fe233e9b5e358e2be61c855773b);
#
#
#             var marker_9efc9b0cc112a843691684a5382164ad = L.marker(
#                 [52.52, 13.405],
#                 {}
#             ).addTo(map_9c579fe233e9b5e358e2be61c855773b);
#
#
#         var popup_efb1ca35703bb1e64f39911e07b0f0e8 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_f0e0c2ead4ea9924264a3a6e23127953 = $(`&lt;div id=&quot;html_f0e0c2ead4ea9924264a3a6e23127953&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Berlin&lt;/div&gt;`)[0];
#                 popup_efb1ca35703bb1e64f39911e07b0f0e8.setContent(html_f0e0c2ead4ea9924264a3a6e23127953);
#
#
#
#         marker_9efc9b0cc112a843691684a5382164ad.bindPopup(popup_efb1ca35703bb1e64f39911e07b0f0e8)
#         ;
#
#
#
#
#             var marker_255368a278f5ce821223ff4a43292822 = L.marker(
#                 [48.7775, 9.18],
#                 {}
#             ).addTo(map_9c579fe233e9b5e358e2be61c855773b);
#
#
#         var popup_72ec946ab70c8d7f767426ed000b0804 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_b10f9373ce91f735f792f7a8a63ad327 = $(`&lt;div id=&quot;html_b10f9373ce91f735f792f7a8a63ad327&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Stuttgart&lt;/div&gt;`)[0];
#                 popup_72ec946ab70c8d7f767426ed000b0804.setContent(html_b10f9373ce91f735f792f7a8a63ad327);
#
#
#
#         marker_255368a278f5ce821223ff4a43292822.bindPopup(popup_72ec946ab70c8d7f767426ed000b0804)
#         ;
#
#
#
#
#             var marker_03db4bb9bd9cd87bf6dc3c0c311134dd = L.marker(
#                 [48.1375, 11.575],
#                 {}
#             ).addTo(map_9c579fe233e9b5e358e2be61c855773b);
#
#
#         var popup_6cbcd7f38f8241d770c865dff4fa33b1 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_add313da2b25b54a95d103d4338d8d1d = $(`&lt;div id=&quot;html_add313da2b25b54a95d103d4338d8d1d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Munich&lt;/div&gt;`)[0];
#                 popup_6cbcd7f38f8241d770c865dff4fa33b1.setContent(html_add313da2b25b54a95d103d4338d8d1d);
#
#
#
#         marker_03db4bb9bd9cd87bf6dc3c0c311134dd.bindPopup(popup_6cbcd7f38f8241d770c865dff4fa33b1)
#         ;
#
#
#
#
#             var marker_75247d32c5f65b2db2c8b5de8fe9b249 = L.marker(
#                 [53.55, 10.0],
#                 {}
#             ).addTo(map_9c579fe233e9b5e358e2be61c855773b);
#
#
#         var popup_d000d7c0c9faafbfbb2d1534f1f8df0e = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_29a04025e5ee8971a472195422998488 = $(`&lt;div id=&quot;html_29a04025e5ee8971a472195422998488&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Hamburg&lt;/div&gt;`)[0];
#                 popup_d000d7c0c9faafbfbb2d1534f1f8df0e.setContent(html_29a04025e5ee8971a472195422998488);
#
#
#
#         marker_75247d32c5f65b2db2c8b5de8fe9b249.bindPopup(popup_d000d7c0c9faafbfbb2d1534f1f8df0e)
#         ;
#
#
#
#
#             var marker_6e4d3dd5df888d9917ec2fb659d6f281 = L.marker(
#                 [50.9364, 6.9528],
#                 {}
#             ).addTo(map_9c579fe233e9b5e358e2be61c855773b);
#
#
#         var popup_bd8d9875c56f191949eb60684263d91f = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_f692efb6d1a6edb33ea568494f366cf0 = $(`&lt;div id=&quot;html_f692efb6d1a6edb33ea568494f366cf0&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Cologne&lt;/div&gt;`)[0];
#                 popup_bd8d9875c56f191949eb60684263d91f.setContent(html_f692efb6d1a6edb33ea568494f366cf0);
#
#
#
#         marker_6e4d3dd5df888d9917ec2fb659d6f281.bindPopup(popup_bd8d9875c56f191949eb60684263d91f)
#         ;
#
#
#
#
#             var marker_f691bbe71f2ab0963927ce265c208b40 = L.marker(
#                 [50.1106, 8.6822],
#                 {}
#             ).addTo(map_9c5

# %% [markdown]
# You just made your first map, congratulations!
#
#
#
#
# .

# %% [markdown]
# **Change marker symbols to 'CircleMarkers'**

# %%
# create basemap OSM
map = folium.Map([51.57, 14.37], zoom_start=6)

# add data layer cities
for i, row in data.iterrows():
    folium.CircleMarker([row['latitude'], row['longitude']], popup=row['city'], radius=5, color='green', fill=True, fill_color='black'
    ).add_to(map)
    
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_6d5bf47513374ac96f4aba601538e78a {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_6d5bf47513374ac96f4aba601538e78a&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_6d5bf47513374ac96f4aba601538e78a = L.map(
#                 &quot;map_6d5bf47513374ac96f4aba601538e78a&quot;,
#                 {
#                     center: [51.57, 14.37],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 6,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_c605573eabcbfbcf15cdf32a871515df = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_c605573eabcbfbcf15cdf32a871515df.addTo(map_6d5bf47513374ac96f4aba601538e78a);
#
#
#             var circle_marker_2534c6c3aa93eb4b848ae0e42efd09fc = L.circleMarker(
#                 [52.52, 13.405],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;green&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;black&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 5, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_6d5bf47513374ac96f4aba601538e78a);
#
#
#         var popup_ceb355364db4bad48a8f439339a32eef = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_68a5ff21927de0583dee72689fe51921 = $(`&lt;div id=&quot;html_68a5ff21927de0583dee72689fe51921&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Berlin&lt;/div&gt;`)[0];
#                 popup_ceb355364db4bad48a8f439339a32eef.setContent(html_68a5ff21927de0583dee72689fe51921);
#
#
#
#         circle_marker_2534c6c3aa93eb4b848ae0e42efd09fc.bindPopup(popup_ceb355364db4bad48a8f439339a32eef)
#         ;
#
#
#
#
#             var circle_marker_7a70bd1dabf809828d500c3bf867156a = L.circleMarker(
#                 [48.7775, 9.18],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;green&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;black&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 5, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_6d5bf47513374ac96f4aba601538e78a);
#
#
#         var popup_1433079c3d2fd05e1dd135bf296ce464 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_7c516a1a77ee07137035403544611657 = $(`&lt;div id=&quot;html_7c516a1a77ee07137035403544611657&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Stuttgart&lt;/div&gt;`)[0];
#                 popup_1433079c3d2fd05e1dd135bf296ce464.setContent(html_7c516a1a77ee07137035403544611657);
#
#
#
#         circle_marker_7a70bd1dabf809828d500c3bf867156a.bindPopup(popup_1433079c3d2fd05e1dd135bf296ce464)
#         ;
#
#
#
#
#             var circle_marker_8abb36291db70620ef6ef837bb3e0b05 = L.circleMarker(
#                 [48.1375, 11.575],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;green&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;black&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 5, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_6d5bf47513374ac96f4aba601538e78a);
#
#
#         var popup_6d2cc6dc52c0a2e454b93aca394f3c03 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_3f849c39ce56972a71ae3d3a64f216a8 = $(`&lt;div id=&quot;html_3f849c39ce56972a71ae3d3a64f216a8&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Munich&lt;/div&gt;`)[0];
#                 popup_6d2cc6dc52c0a2e454b93aca394f3c03.setContent(html_3f849c39ce56972a71ae3d3a64f216a8);
#
#
#
#         circle_marker_8abb36291db70620ef6ef837bb3e0b05.bindPopup(popup_6d2cc6dc52c0a2e454b93aca394f3c03)
#         ;
#
#
#
#
#             var circle_marker_226eb0f6f7719beacb1519cf1ed63bc8 = L.circleMarker(
#                 [53.55, 10.0],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;green&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;black&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &q

# %% [markdown]
# ## Add heatmap layer: population

# %%
from folium.plugins import HeatMap

# prepate heatmap_data
hm_data = []
for i, row in data.iterrows():
    hm_data.append([row['latitude'], row['longitude'], row['population']])

# add heatmap layer to map
HeatMap(hm_data
    ).add_to(map)
    
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_6d5bf47513374ac96f4aba601538e78a {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium@main/folium/templates/leaflet_heat.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_6d5bf47513374ac96f4aba601538e78a&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_6d5bf47513374ac96f4aba601538e78a = L.map(
#                 &quot;map_6d5bf47513374ac96f4aba601538e78a&quot;,
#                 {
#                     center: [51.57, 14.37],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 6,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_c605573eabcbfbcf15cdf32a871515df = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_c605573eabcbfbcf15cdf32a871515df.addTo(map_6d5bf47513374ac96f4aba601538e78a);
#
#
#             var circle_marker_2534c6c3aa93eb4b848ae0e42efd09fc = L.circleMarker(
#                 [52.52, 13.405],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;green&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;black&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 5, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_6d5bf47513374ac96f4aba601538e78a);
#
#
#         var popup_ceb355364db4bad48a8f439339a32eef = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_68a5ff21927de0583dee72689fe51921 = $(`&lt;div id=&quot;html_68a5ff21927de0583dee72689fe51921&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Berlin&lt;/div&gt;`)[0];
#                 popup_ceb355364db4bad48a8f439339a32eef.setContent(html_68a5ff21927de0583dee72689fe51921);
#
#
#
#         circle_marker_2534c6c3aa93eb4b848ae0e42efd09fc.bindPopup(popup_ceb355364db4bad48a8f439339a32eef)
#         ;
#
#
#
#
#             var circle_marker_7a70bd1dabf809828d500c3bf867156a = L.circleMarker(
#                 [48.7775, 9.18],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;green&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;black&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 5, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_6d5bf47513374ac96f4aba601538e78a);
#
#
#         var popup_1433079c3d2fd05e1dd135bf296ce464 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_7c516a1a77ee07137035403544611657 = $(`&lt;div id=&quot;html_7c516a1a77ee07137035403544611657&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Stuttgart&lt;/div&gt;`)[0];
#                 popup_1433079c3d2fd05e1dd135bf296ce464.setContent(html_7c516a1a77ee07137035403544611657);
#
#
#
#         circle_marker_7a70bd1dabf809828d500c3bf867156a.bindPopup(popup_1433079c3d2fd05e1dd135bf296ce464)
#         ;
#
#
#
#
#             var circle_marker_8abb36291db70620ef6ef837bb3e0b05 = L.circleMarker(
#                 [48.1375, 11.575],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;green&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;black&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 5, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_6d5bf47513374ac96f4aba601538e78a);
#
#
#         var popup_6d2cc6dc52c0a2e454b93aca394f3c03 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_3f849c39ce56972a71ae3d3a64f216a8 = $(`&lt;div id=&quot;html_3f849c39ce56972a71ae3d3a64f216a8&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Munich&lt;/div&gt;`)[0];
#                 popup_6d2cc6dc52c0a2e454b93aca394f3c03.setContent(html_3f849c39ce56972a71ae3d3a64f216a8);
#
#
#
#         circle_marker_8abb36291db70620ef6ef837bb3e0b05.bindPopup(popup_6d2cc6dc52c0a2e454b93aca394f3c03)
#         ;
#
#
#
#
#             var circle_marker_226eb0f6f7719beacb1519cf1ed63bc8 = L.circleMarker(
#                 [53.55, 10.0],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;green&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;:

# %% [markdown]
# Well done! You've already created a basemap with two layers :)
#
#
#
# .

# %% [markdown]
# # _Concessions_
#
# _I know i promised more in the introduction, and i intend to continue here with geopandas and geometry format._
#
# _But -sadly- it's time for bed now._
#
# _You've made your first map! So stopp nagging :)_
#
# _Good n8 and CU soon!_

# %% [markdown]
# # Conclusion as send off for the night -haha-

# %%
def folium_map():
    import pandas as pd
    import folium
    from folium.plugins import HeatMap

    # load data with latitude and lognitude as float
    data = pd.read_csv("some_cities_data.csv", index_col=None)

    # create basemap OSM
    map = folium.Map([51.57, 14.37], zoom_start=6)

    # add data layer cities
    for i, row in data.iterrows():
        folium.CircleMarker([row['latitude'], row['longitude']], popup=row['city'], radius=1.2, color='darkblue'
        ).add_to(map)

    # prepate heatmap_data
    hm_data = []
    for i, row in data.iterrows():
        hm_data.append([row['latitude'], row['longitude'], row['population']])

    # add heatmap layer population
    HeatMap(hm_data
        ).add_to(map)
    return map

# %%
folium_map()
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_086e123df89d69221bdf1856d082c153 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium@main/folium/templates/leaflet_heat.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_086e123df89d69221bdf1856d082c153&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_086e123df89d69221bdf1856d082c153 = L.map(
#                 &quot;map_086e123df89d69221bdf1856d082c153&quot;,
#                 {
#                     center: [51.57, 14.37],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 6,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_3974d980a033edb31cb3bce4cd0fc288 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_3974d980a033edb31cb3bce4cd0fc288.addTo(map_086e123df89d69221bdf1856d082c153);
#
#
#             var circle_marker_97c65501776b8d490a439db6cc44c986 = L.circleMarker(
#                 [52.52, 13.405],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;darkblue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;darkblue&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 1.2, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_086e123df89d69221bdf1856d082c153);
#
#
#         var popup_e8a3c9c176d9ab6badfe7e50ddea538c = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_b3655e051ac0922e94c71d06419418b8 = $(`&lt;div id=&quot;html_b3655e051ac0922e94c71d06419418b8&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Berlin&lt;/div&gt;`)[0];
#                 popup_e8a3c9c176d9ab6badfe7e50ddea538c.setContent(html_b3655e051ac0922e94c71d06419418b8);
#
#
#
#         circle_marker_97c65501776b8d490a439db6cc44c986.bindPopup(popup_e8a3c9c176d9ab6badfe7e50ddea538c)
#         ;
#
#
#
#
#             var circle_marker_c250116a1a6cab65c693a52d237f3afc = L.circleMarker(
#                 [48.7775, 9.18],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;darkblue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;darkblue&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 1.2, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_086e123df89d69221bdf1856d082c153);
#
#
#         var popup_833fd4c6f8c46d71245ddf77b06033d7 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_9aaacdc7cba309d379e74f219d3b24f6 = $(`&lt;div id=&quot;html_9aaacdc7cba309d379e74f219d3b24f6&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Stuttgart&lt;/div&gt;`)[0];
#                 popup_833fd4c6f8c46d71245ddf77b06033d7.setContent(html_9aaacdc7cba309d379e74f219d3b24f6);
#
#
#
#         circle_marker_c250116a1a6cab65c693a52d237f3afc.bindPopup(popup_833fd4c6f8c46d71245ddf77b06033d7)
#         ;
#
#
#
#
#             var circle_marker_3925d30c84390e31e1efb37929fab706 = L.circleMarker(
#                 [48.1375, 11.575],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;darkblue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;darkblue&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 1.2, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_086e123df89d69221bdf1856d082c153);
#
#
#         var popup_6d40e07614c3de0cd7e41050addc805c = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_6997e066e6472b334c7ab4eeb062d064 = $(`&lt;div id=&quot;html_6997e066e6472b334c7ab4eeb062d064&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Munich&lt;/div&gt;`)[0];
#                 popup_6d40e07614c3de0cd7e41050addc805c.setContent(html_6997e066e6472b334c7ab4eeb062d064);
#
#
#
#         circle_marker_3925d30c84390e31e1efb37929fab706.bindPopup(popup_6d40e07614c3de0cd7e41050addc805c)
#         ;
#
#
#
#
#             var circle_marker_61cb2e876d90937a5235a71071cbd1e1 = L.circleMarker(
#                 [53.55, 10.0],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;darkblue&quot;, &quot;dashArray&quot;:

# %%
map.save('map_cities_population.html')
